# %% [markdown]
# <a href="https://colab.research.google.com/github/ancestor9/Introduction-to-BigData-Analysis/blob/main/14%EC%A3%BC%EC%B0%A8/ML/AdventureSales_02_data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **[Tutorial: From Excel workbook to a Power BI report in Microsoft Teams](https://learn.microsoft.com/en-us/power-bi/create-reports/service-from-excel-to-stunning-report)**
#
#
# <img src='https://learn.microsoft.com/en-us/power-bi/create-reports/media/service-from-excel-to-stunning-report/power-bi-financial-report-service.png'>

# %% [markdown]
# ## **1. 데이터 다운로드 하기**

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# >> #### 1.2. Linux Bash 명령어로 다운 받는 법

# %%
# Linux Bash 명령어
! wget https://github.com/microsoft/powerbi-desktop-samples/raw/main/AdventureWorks%20Sales%20Sample/AdventureWorks%20Sales.xlsx
# Out:
# --2025-07-23 05:55:37--  https://github.com/microsoft/powerbi-desktop-samples/raw/main/AdventureWorks%20Sales%20Sample/AdventureWorks%20Sales.xlsx
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/microsoft/powerbi-desktop-samples/main/AdventureWorks%20Sales%20Sample/AdventureWorks%20Sales.xlsx [following]
# --2025-07-23 05:55:38--  https://raw.githubusercontent.com/microsoft/powerbi-desktop-samples/main/AdventureWorks%20Sales%20Sample/AdventureWorks%20Sales.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14322931 (14M) [application/octet-stream]
# Saving to: ‘AdventureWorks Sales.xlsx’
#
# AdventureWorks Sale 100%[===================>]  13.66M  73.4MB/s    in 0.2s
#
# 2025-07-23 05:55:38 (73.4 MB/s) - ‘AdventureWorks Sales.xlsx’ saved [14322931/14322931]

# %%
# prompt: AdventureWorks Sales.xlsx는 7개의 시트(고객, 상품, 지역, 판매 등)를 모두 읽고 사전형태로 데이터를 저장해 다오
# To read multiple sheets from a single Excel file, we will use the pandas library.
# Below is an example of how you can read all sheets from an Excel file into a dictionary of DataFrames.

import pandas as pd

# Function to read all sheets from an Excel file
def read_excel_sheets(excel_file):
    # Using sheet_name=None reads all sheets, each sheet as a DataFrame in a dictionary
    sheets_dict = pd.read_excel(excel_file, sheet_name=None)
    return sheets_dict

dfs = read_excel_sheets('/content/AdventureWorks Sales.xlsx')
dfs.keys()
# Out:
# dict_keys(['Sales Order_data', 'Sales Territory_data', 'Sales_data', 'Reseller_data', 'Date_data', 'Product_data', 'Customer_data'])

# %%
# prompt: dfs의 모든 시트를 csv파일로 각각 저장해줘

import os

# Create a directory to save the CSV files
output_dir = 'csv_sheets'
os.makedirs(output_dir, exist_ok=True)

# Iterate through the sheets and save each as a CSV file
for sheet_name, df in dfs.items():
  # Sanitize sheet names to be valid filenames
  sanitized_sheet_name = sheet_name.replace('/', '_').replace('\\', '_').replace(':', '_').replace('*', '_').replace('?', '_').replace('"', '_').replace('<', '_').replace('>', '_').replace('|', '_')
  output_filename = os.path.join(output_dir, f'{sanitized_sheet_name}.csv')
  df.to_csv(output_filename, index=False)
  print(f"Saved sheet '{sheet_name}' to '{output_filename}'")

# List the created files (optional)
# !ls csv_sheets
# Out:
# Saved sheet 'Sales Order_data' to 'csv_sheets/Sales Order_data.csv'
# Saved sheet 'Sales Territory_data' to 'csv_sheets/Sales Territory_data.csv'
# Saved sheet 'Sales_data' to 'csv_sheets/Sales_data.csv'
# Saved sheet 'Reseller_data' to 'csv_sheets/Reseller_data.csv'
# Saved sheet 'Date_data' to 'csv_sheets/Date_data.csv'
# Saved sheet 'Product_data' to 'csv_sheets/Product_data.csv'
# Saved sheet 'Customer_data' to 'csv_sheets/Customer_data.csv'
#  Customer_data.csv   Reseller_data.csv	    'Sales Territory_data.csv'
#  Date_data.csv	     Sales_data.csv
#  Product_data.csv   'Sales Order_data.csv'

# %%
# prompt: tf의 자료형태, 결측치, 고유값, 대표갑 7개를 데이터프레임으로 보여주는 함수를 아주 간단하게 달라. 아주 간단하게, 주석은 뺴고

import pandas as pd
def summary(df):
    analysis_data = []
    for col in df.columns:
        dtype = df[col].dtype
        missing_count = df[col].isnull().sum()
        missing_percentage = missing_count / len(df) * 100
        unique_count = df[col].nunique()
        top_7_values = df[col].value_counts().nlargest(7).index.tolist()
        analysis_data.append([col, dtype, missing_count, missing_percentage, unique_count, top_7_values])
    analysis_df = pd.DataFrame(analysis_data, columns=['Column', 'DataType', 'MissingCount', 'missing_percentage', 'UniqueCount', 'Top7Values'])
    return analysis_df

# %%
# prompt: dfs의 모든 데이터프레임에  analyze_dataframe()함수를 적용하여 차례대로 보여줘

from IPython.display import display

for sheet_name, df in dfs.items():
    print(f"Analyzing DataFrame for sheet: {sheet_name}")
    analysis_result = summary(df)
    display(analysis_result)
    print("-" * 100) # Separator for better readability
    print("-" * 100) # Separator for better readability
# Out:
# Analyzing DataFrame for sheet: Sales Order_data
#               Column DataType  MissingCount  missing_percentage  UniqueCount  \
# 0            Channel   object             0                 0.0            2
# 1  SalesOrderLineKey    int64             0                 0.0       121253
# 2        Sales Order   object             0                 0.0        31455
# 3   Sales Order Line   object             0                 0.0       121253
#
#                                           Top7Values
# 0                               [Reseller, Internet]
# 1  [75123003, 43659001, 43659002, 43659003, 43659...
# 2  [SO51721, SO51739, SO51160, SO53465, SO47355, ...
# 3  [SO75123 - 3, SO43659 - 1, SO43659 - 2, SO4365...
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Analyzing DataFrame for sheet: Sales Territory_data
#               Column DataType  MissingCount  missing_percentage  UniqueCount  \
# 0  SalesTerritoryKey    int64             0                 0.0           11
# 1             Region   object             0                 0.0           11
# 2            Country   object             0                 0.0            7
# 3              Group   object             0                 0.0            4
#
#                                           Top7Values
# 0                              [1, 2, 3, 4, 5, 6, 7]
# 1  [Northwest, Northeast, Central, Southwest, Sou...
# 2  [United States, Canada, France, Germany, Austr...
# 3     [North America, Europe, Pacific, Corporate HQ]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Analyzing DataFrame for sheet: Sales_data
#                      Column DataType  MissingCount  missing_percentage  \
# 0         SalesOrderLineKey    int64             0            0.000000
# 1               ResellerKey    int64             0            0.000000
# 2               CustomerKey    int64             0            0.000000
# 3                ProductKey    int64             0            0.000000
# 4              OrderDateKey    int64             0            0.000000
# 5                DueDateKey    int64             0            0.000000
# 6               ShipDateKey  float64          2113            1.742637
# 7         SalesTerritoryKey    int64             0            0.000000
# 8            Order Quantity    int64             0            0.000000
# 9                Unit Price  float64             0            0.000000
# 10          Extended Amount  float64             0            0.000000
# 11  Unit Price Discount Pct    int64             0            0.000000
# 12    Product Standard Cost  float64             0            0.000000
# 13       Total Product Cost  float64             0            0.000000
# 14             Sales Amount  float64             0            0.000000
#
#     UniqueCount                                         Top7Values
# 0        121253  [75123003, 43659001, 43659002, 43659003, 43659...
# 1           636                  [-1, 678, 54, 514, 118, 496, 175]
# 2         18485     [-1, 11185, 11300, 11277, 11262, 11287, 11176]
# 3           350                [477, 480, 528, 225, 214, 222, 217]
# 4          1081  [20200606, 20200615, 20190905, 20200602, 20200...
# 5          1081  [20200616, 20200625, 20190915, 20200612, 20200...
# 6          1074  [20200613.0, 20190912.0, 20200609.0, 20200521....
# 7            10                             [4, 6, 1, 9, 10, 7, 8]
# 8            41                              [1, 2, 3, 4, 5, 6, 7]
# 9           275  [4.99, 34.99, 8.99, 2.29, 469.794, 3.99, 419.4...
# 10         1444       [4.99, 34.99, 8.99, 2.29, 3.99, 21.98, 9.99]
# 11            1                                                [0]
# 12          125  [1.8663, 13.0863, 486.7066, 0.8565, 1481.9379,...
# 13         1453  [1.8663, 13.0863, 0.8565, 1.4923, 3.3623, 6.92...
# 14         1464       [4.99, 34.99, 8.99, 2.29, 3.99, 21.98, 9.99]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Analyzing DataFrame for sheet: Reseller_data
#            Column DataType  MissingCount  missing_percentage  UniqueCount  \
# 0     ResellerKey    int64             0                 0.0          702
# 1     Reseller ID   object             0                 0.0          702
# 2   Business Type   object             0                 0.0            4
# 3        Reseller   object             0                 0.0          700
# 4            City   object             0                 0.0          452
# 5  State-Province   object             0                 0.0           66
# 6  Country-Region   object             0                 0.0            7
# 7     Postal Code   object             0                 0.0          502
#
#                                           Top7Values
# 0                           [701, -1, 1, 2, 3, 4, 5]
# 1  [AW00000701, [Not Applicable], AW00000001, AW0...
# 2  [Value Added Reseller, Warehouse, Specialty Bi...
# 3  [Friendly Bike Shop, Sports Products Store, Pr...
# 4  [Toronto, London, Paris, Montreal, Calgary, Mi...
# 5  [California, Ontario, Washington, England, Tex...
# 6  [United States, Canada, France, Australia, Ger...
# 7  [T2P 2G8, 33127, M4B 1V7, M4B 1V5, 78204, H1Y ...
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Analyzing DataFrame for sheet: Date_data
#            Column        DataType  MissingCount  missing_percentage  \
# 0         DateKey           int64             0                 0.0
# 1            Date  datetime64[ns]             0                 0.0
# 2     Fiscal Year          object             0                 0.0
# 3  Fiscal Quarter          object             0                 0.0
# 4           Month          object             0                 0.0
# 5       Full Date          object             0                 0.0
# 6        MonthKey           int64             0                 0.0
#
#    UniqueCount                                         Top7Values
# 0         1461  [20210630, 20170701, 20170702, 20170703, 20170...
# 1         1461  [2021-06-30 00:00:00, 2017-07-01 00:00:00, 201...
# 2            4                   [FY2020, FY2018, FY2019, FY2021]
# 3           16  [FY2018 Q1, FY2018 Q2, FY2019 Q2, FY2019 Q1, F...
# 4           48  [2017 Jul, 2017 Aug, 2017 Oct, 2017 Dec, 2018 ...
# 5         1461  [2021 Jun, 30, 2017 Jul, 01, 2017 Jul, 02, 201...
# 6           48  [201707, 201708, 201710, 201712, 201801, 20180...
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Analyzing DataFrame for sheet: Product_data
#           Column DataType  MissingCount  missing_percentage  UniqueCount  \
# 0     ProductKey    int64             0            0.000000          397
# 1            SKU   object             0            0.000000          295
# 2        Product   object             0            0.000000          295
# 3  Standard Cost  float64             0            0.000000          134
# 4          Color   object            56           14.105793            9
# 5     List Price  float64             0            0.000000          120
# 6          Model   object             0            0.000000          119
# 7    Subcategory   object             0            0.000000           37
# 8       Category   object             0            0.000000            4
#
#                                           Top7Values
# 0                [606, 210, 211, 212, 213, 214, 215]
# 1  [FR-R38B-44, FR-R38B-58, FR-R38B-62, FR-R38B-6...
# 2  [LL Road Frame - Black, 44, LL Road Frame - Bl...
# 3  [413.1463, 486.7066, 868.6342, 461.4448, 199.8...
# 4  [Black, Red, Yellow, Silver, Blue, Multi, Silv...
# 5  [699.0982, 782.99, 337.22, 306.5636, 1431.5, 5...
# 6  [LL Road Frame, HL Road Frame, Road-650, HL Mo...
# 7  [Road Frames, Road Bikes, Mountain Frames, Mou...
# 8         [Components, Bikes, Clothing, Accessories]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Analyzing DataFrame for sheet: Customer_data
#            Column DataType  MissingCount  missing_percentage  UniqueCount  \
# 0     CustomerKey    int64             0                 0.0        18485
# 1     Customer ID   object             0                 0.0        18485
# 2        Customer   object             0                 0.0        18401
# 3            City   object             0                 0.0          270
# 4  State-Province   object             0                 0.0           54
# 5  Country-Region   object             0                 0.0            7
# 6     Postal Code   object             0                 0.0          324
#
#                                           Top7Values
# 0     [29483, -1, 11000, 11001, 11002, 29467, 29466]
# 1  [AW00029483, [Not Applicable], AW00011000, AW0...
# 2  [Mohamed Pal, Alejandro Xu, Janet Torres, Kait...
# 3  [London, Paris, Burien, Concord, Bellingham, B...
# 4  [California, Washington, England, British Colu...
# 5  [United States, Australia, United Kingdom, Fra...
# 6     [94519, 98168, 97005, 98225, 91910, 91950, V9]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %%
# Save the analysis results of each sheet into a single Excel file
output_excel_path = '/content/analysis_results.xlsx'

with pd.ExcelWriter(output_excel_path) as writer:
    for sheet_name, df in dfs.items():
        print(f"Analyzing and saving analysis for sheet: {sheet_name}")
        analysis_result = summary(df)
        analysis_result.to_excel(writer, sheet_name=sheet_name, index=False)
        print(f"Saved analysis for sheet '{sheet_name}' to '{output_excel_path}'")
        print("-" * 100) # Separator for better readability

print(f"\nAll analysis results saved to: {output_excel_path}")
# Out:
# Analyzing and saving analysis for sheet: Sales Order_data
# Saved analysis for sheet 'Sales Order_data' to '/content/analysis_results.xlsx'
# ----------------------------------------------------------------------------------------------------
# Analyzing and saving analysis for sheet: Sales Territory_data
# Saved analysis for sheet 'Sales Territory_data' to '/content/analysis_results.xlsx'
# ----------------------------------------------------------------------------------------------------
# Analyzing and saving analysis for sheet: Sales_data
# Saved analysis for sheet 'Sales_data' to '/content/analysis_results.xlsx'
# ----------------------------------------------------------------------------------------------------
# Analyzing and saving analysis for sheet: Reseller_data
# Saved analysis for sheet 'Reseller_data' to '/content/analysis_results.xlsx'
# ----------------------------------------------------------------------------------------------------
# Analyzing and saving analysis for sheet: Date_data
# Saved analysis for sheet 'Date_data' to '/content/analysis_results.xlsx'
# ----------------------------------------------------------------------------------------------------
# Analyzing and saving analysis for sheet: Product_data
# Saved analysis for sheet 'Product_data' to '/content/analysis_results.xlsx'
# ----------------------------------------------------------------------------------------------------
# Analyzing and saving analysis for sheet: Customer_data
# Saved analysis for sheet 'Customer_data' to '/content/analysis_results.xlsx'
# ----------------------------------------------------------------------------------------------------
#
# All analysis results saved to: /content/analysis_results.xlsx

# %%
import pandas as pd

# 1. CSV 파일 로드
sales = pd.read_csv("/content/csv_sheets/Sales_data.csv")
sales_order = pd.read_csv("/content/csv_sheets/Sales Order_data.csv")
reseller = pd.read_csv("/content/csv_sheets/Reseller_data.csv")
product = pd.read_csv("/content/csv_sheets/Product_data.csv")
date = pd.read_csv("/content/csv_sheets/Date_data.csv")
customer = pd.read_csv("/content/csv_sheets/Customer_data.csv")
territory = pd.read_csv("/content/csv_sheets/Sales Territory_data.csv")

# 2. 병합 수행
merged = pd.merge(sales, sales_order, on='SalesOrderLineKey', how='left')
merged = pd.merge(merged, reseller, on='ResellerKey', how='left')
merged = pd.merge(merged, product, on='ProductKey', how='left')
merged = pd.merge(merged, date, left_on='OrderDateKey', right_on='DateKey', how='left')
merged = pd.merge(merged, customer, on='CustomerKey', how='left')
merged = pd.merge(merged, territory, on='SalesTerritoryKey', how='left')  # 중요 병합

# 3. 최종 결과 저장
# merged.to_csv("/content/csv_sheets/Merged_All_Data.csv", index=False)

merged
# Out:
#         SalesOrderLineKey  ResellerKey  CustomerKey  ProductKey  OrderDateKey  \
# 0                43659001          676           -1         349      20170702
# 1                43659002          676           -1         350      20170702
# 2                43659003          676           -1         351      20170702
# 3                43659004          676           -1         344      20170702
# 4                43659005          676           -1         345      20170702
# ...                   ...          ...          ...         ...           ...
# 121248           75122001           -1        15868         485      20200615
# 121249           75122002           -1        15868         225      20200615
# 121250           75123001           -1        18759         485      20200615
# 121251           75123002           -1        18759         486      20200615
# 121252           75123003           -1        18759         225      20200615
#
#         DueDateKey  ShipDateKey  SalesTerritoryKey  Order Quantity  \
# 0         20170712   20170709.0                  5               1
# 1         20170712   20170709.0                  5               3
# 2         20170712   20170709.0                  5               1
# 3         20170712   20170709.0                  5               1
# 4         20170712   20170709.0                  5               1
# ...            ...          ...                ...             ...
# 121248    20200625          NaN                  6               1
# 121249    20200625          NaN                  6               1
# 121250    20200625          NaN                  6               1
# 121251    20200625          NaN                  6               1
# 121252    20200625          NaN                  6               1
#
#         Unit Price  ...  MonthKey       Customer ID          Customer  \
# 0         2024.994  ...    201707  [Not Applicable]  [Not Applicable]
# 1         2024.994  ...    201707  [Not Applicable]  [Not Applicable]
# 2         2024.994  ...    201707  [Not Applicable]  [Not Applicable]
# 3         2039.994  ...    201707  [Not Applicable]  [Not Applicable]
# 4         2039.994  ...    201707  [Not Applicable]  [Not Applicable]
# ...            ...  ...       ...               ...               ...
# 121248      21.980  ...    202006        AW00015868         Caleb Lal
# 121249       8.990  ...    202006        AW00015868         Caleb Lal
# 121250      21.980  ...    202006        AW00018759    Devin Phillips
# 121251     159.000  ...    202006        AW00018759    Devin Phillips
# 121252       8.990  ...    202006        AW00018759    Devin Phillips
#
#                   City_y  State-Province_y  Country-Region_y  \
# 0       [Not Applicable]  [Not Applicable]  [Not Applicable]
# 1       [Not Applicable]  [Not Applicable]  [Not Applicable]
# 2       [Not Applicable]  [Not Applicable]  [Not Applicable]
# 3       [Not Applicable]  [Not Applicable]  [Not Applicable]
# 4       [Not Applicable]  [Not Applicable]  [Not Applicable]
# ...                  ...               ...               ...
# 121248             Sooke  British Columbia            Canada
# 121249             Sooke  British Columbia            Canada
# 121250             Sooke  British Columbia            Canada
# 121251             Sooke  British Columbia            Canada
# 121252             Sooke  British Columbia            Canada
#
#            Postal Code_y     Region        Country          Group
# 0       [Not Applicable]  Southeast  United States  North America
# 1       [Not Applicable]  Southeast  United States  North America
# 2       [Not Applicable]  Southeast  United States  North America
# 3       [Not Applicable]  Southeast  United States  North America
# 4       [Not Applicable]  Southeast  United States  North America
# ...                  ...        ...            ...            ...
# 121248                V0     Canada         Canada  North America
# 121249                V0     Canada         Canada  North America
# 121250                V0     Canada         Canada  North America
# 121251                V0     Canada         Canada  North America
# 121252                V0     Canada         Canada  North America
#
# [121253 rows x 49 columns]

# %%
merged.columns
# Out:
# Index(['SalesOrderLineKey', 'ResellerKey', 'CustomerKey', 'ProductKey',
#        'OrderDateKey', 'DueDateKey', 'ShipDateKey', 'SalesTerritoryKey',
#        'Order Quantity', 'Unit Price', 'Extended Amount',
#        'Unit Price Discount Pct', 'Product Standard Cost',
#        'Total Product Cost', 'Sales Amount', 'Channel', 'Sales Order',
#        'Sales Order Line', 'Reseller ID', 'Business Type', 'Reseller',
#        'City_x', 'State-Province_x', 'Country-Region_x', 'Postal Code_x',
#        'SKU', 'Product', 'Standard Cost', 'Color', 'List Price', 'Model',
#        'Subcategory', 'Category', 'DateKey', 'Date', 'Fiscal Year',
#        'Fiscal Quarter', 'Month', 'Full Date', 'MonthKey', 'Customer ID',
#        'Customer', 'City_y', 'State-Province_y', 'Country-Region_y',
#        'Postal Code_y', 'Region', 'Country', 'Group'],
#       dtype='object')

# %%
# prompt: merged_df의 Extended Amount, Unit Price Discount Pct 를 drop하라

merged_df = merged.drop(columns=['Extended Amount', 'Unit Price Discount Pct'])

# %%
# prompt: merged_df의 컬럼명이 "_y"로 끝나는 컬럼은 drop하고 "_x"로 끝나는 컬럼명은  "_x" 글자를 제거하라

# 컬럼 정리 (suffix 제거)
cols_to_drop = [col for col in merged_df.columns if col.endswith('_y')]
cols_to_rename = {col: col.replace('_x', '') for col in merged_df.columns if col.endswith('_x')}

merged_df = merged_df.drop(columns=cols_to_drop)
merged_df = merged_df.rename(columns=cols_to_rename)

summary(merged_df).sort_values(by='Column', ascending=False)
# Out:
#                    Column DataType  MissingCount  missing_percentage  \
# 9              Unit Price  float64             0            0.000000
# 11     Total Product Cost  float64             0            0.000000
# 29            Subcategory   object             0            0.000000
# 20         State-Province   object             0            0.000000
# 25          Standard Cost  float64             0            0.000000
# 6             ShipDateKey  float64          2113            1.742637
# 7       SalesTerritoryKey    int64             0            0.000000
# 0       SalesOrderLineKey    int64             0            0.000000
# 15       Sales Order Line   object             0            0.000000
# 14            Sales Order   object             0            0.000000
# 12           Sales Amount  float64             0            0.000000
# 23                    SKU   object             0            0.000000
# 1             ResellerKey    int64             0            0.000000
# 16            Reseller ID   object             0            0.000000
# 18               Reseller   object             0            0.000000
# 40                 Region   object             0            0.000000
# 3              ProductKey    int64             0            0.000000
# 10  Product Standard Cost  float64             0            0.000000
# 24                Product   object             0            0.000000
# 22            Postal Code   object             0            0.000000
# 4            OrderDateKey    int64             0            0.000000
# 8          Order Quantity    int64             0            0.000000
# 37               MonthKey    int64             0            0.000000
# 35                  Month   object             0            0.000000
# 28                  Model   object             0            0.000000
# 27             List Price  float64             0            0.000000
# 42                  Group   object             0            0.000000
# 36              Full Date   object             0            0.000000
# 33            Fiscal Year   object             0            0.000000
# 34         Fiscal Quarter   object             0            0.000000
# 5              DueDateKey    int64             0            0.000000
# 31                DateKey    int64             0            0.000000
# 32                   Date   object             0            0.000000
# 2             CustomerKey    int64             0            0.000000
# 38            Customer ID   object             0            0.000000
# 39               Customer   object             0            0.000000
# 21         Country-Region   object             0            0.000000
# 41                Country   object             0            0.000000
# 26                  Color   object         34144           28.159303
# 19                   City   object             0            0.000000
# 13                Channel   object             0            0.000000
# 30               Category   object             0            0.000000
# 17          Business Type   object             0            0.000000
#
#     UniqueCount                                         Top7Values
# 9           275  [4.99, 34.99, 8.99, 2.29, 469.794, 3.99, 419.4...
# 11         1453  [1.8663, 13.0863, 0.8565, 1.4923, 3.3623, 6.92...
# 29           35  [Road Bikes, Tires and Tubes, Mountain Bikes, ...
# 20           65  [[Not Applicable], California, Ontario, Texas,...
# 25          125  [1.8663, 13.0863, 486.7066, 0.8565, 1481.9379,...
# 6          1074  [20200613.0, 20190912.0, 20200609.0, 20200521....
# 7            10                             [4, 6, 1, 9, 10, 7, 8]
# 0        121253  [75123003, 43659001, 43659002, 43659003, 43659...
# 15       121253  [SO75123 - 3, SO43659 - 1, SO43659 - 2, SO4365...
# 14        31455  [SO51721, SO51739, SO51160, SO53465, SO47355, ...
# 12         1464       [4.99, 34.99, 8.99, 2.29, 3.99, 21.98, 9.99]
# 23          266  [WB-H098, CA-1098, PK-7098, TT-M928, HL-U509-B...
# 1           636                  [-1, 678, 54, 514, 118, 496, 175]
# 16          636  [[Not Applicable], AW00000678, AW00000054, AW0...
# 18          634  [[Not Applicable], Vigorous Exercise Company, ...
# 40           10  [Southwest, Canada, Northwest, Australia, Unit...
# 3           350                [477, 480, 528, 225, 214, 222, 217]
# 10          125  [1.8663, 13.0863, 486.7066, 0.8565, 1481.9379,...
# 24          266  [Water Bottle - 30 oz., AWC Logo Cap, Patch Ki...
# 22          463  [[Not Applicable], M4B 1V7, M4B 1V5, V6B 3P7, ...
# 4          1081  [20200606, 20200615, 20190905, 20200602, 20200...
# 8            41                              [1, 2, 3, 4, 5, 6, 7]
# 37           36  [202005, 201911, 201909, 201908, 201912, 20200...
# 35           36  [2020 May, 2019 Nov, 2019 Sep, 2019 Aug, 2019 ...
# 28          107  [Sport-100, Mountain-200, Road-650, Water Bott...
# 27          113   [4.99, 34.99, 8.99, 782.99, 2.29, 539.99, 53.99]
# 42            3                   [North America, Europe, Pacific]
# 36         1081  [2020 Jun, 06, 2020 Jun, 15, 2019 Sep, 05, 202...
# 33            3                           [FY2020, FY2019, FY2018]
# 34           12  [FY2020 Q2, FY2020 Q1, FY2020 Q4, FY2020 Q3, F...
# 5          1081  [20200616, 20200625, 20190915, 20200612, 20200...
# 31         1081  [20200606, 20200615, 20190905, 20200602, 20200...
# 32         1081  [2020-06-06, 2020-06-15, 2019-09-05, 2020-06-0...
# 2         18485     [-1, 11185, 11300, 11277, 11262, 11287, 11176]
# 38        18485  [[Not Applicable], AW00011185, AW00011300, AW0...
# 39        18401  [[Not Applicable], Ashley Henderson, Fernando ...
# 21            7  [[Not Applicable], United States, Canada, Fran...
# 41            6  [United States, Canada, Australia, United King...
# 26            8  [Black, Red, Yellow, Silver, Blue, Multi, Silv...
# 19          417  [[Not Applicable], Toronto, London, Paris, Mon...
# 13            2                               [Reseller, Internet]
# 30            4         [Accessories, Bikes, Clothing, Components]
# 17            4  [[Not Applicable], Warehouse, Value Added Rese...

# %%
# prompt: merged_df를 11개 컬럼으로 순회하면서 보여줘

# Iterate through columns in chunks of 15
num_cols = len(merged_df.columns)
for i in range(0, num_cols, 11):
    cols_to_show = merged_df.columns[i:i+11]
    display(merged_df[cols_to_show].head())
    print("-" * 100) # Separator for better readability
# Out:
#    SalesOrderLineKey  ResellerKey  CustomerKey  ProductKey  OrderDateKey  \
# 0           43659001          676           -1         349      20170702
# 1           43659002          676           -1         350      20170702
# 2           43659003          676           -1         351      20170702
# 3           43659004          676           -1         344      20170702
# 4           43659005          676           -1         345      20170702
#
#    DueDateKey  ShipDateKey  SalesTerritoryKey  Order Quantity  Unit Price  \
# 0    20170712   20170709.0                  5               1    2024.994
# 1    20170712   20170709.0                  5               3    2024.994
# 2    20170712   20170709.0                  5               1    2024.994
# 3    20170712   20170709.0                  5               1    2039.994
# 4    20170712   20170709.0                  5               1    2039.994
#
#    Product Standard Cost
# 0              1898.0944
# 1              1898.0944
# 2              1898.0944
# 3              1912.1544
# 4              1912.1544
# ----------------------------------------------------------------------------------------------------
#    Total Product Cost  Sales Amount   Channel Sales Order Sales Order Line  \
# 0           1898.0944      2024.994  Reseller     SO43659      SO43659 - 1
# 1           5694.2832      6074.982  Reseller     SO43659      SO43659 - 2
# 2           1898.0944      2024.994  Reseller     SO43659      SO43659 - 3
# 3           1912.1544      2039.994  Reseller     SO43659      SO43659 - 4
# 4           1912.1544      2039.994  Reseller     SO43659      SO43659 - 5
#
#   Reseller ID         Business Type          Reseller     City State-Province  \
# 0  AW00000676  Value Added Reseller  Better Bike Shop  Austell        Georgia
# 1  AW00000676  Value Added Reseller  Better Bike Shop  Austell        Georgia
# 2  AW00000676  Value Added Reseller  Better Bike Shop  Austell        Georgia
# 3  AW00000676  Value Added Reseller  Better Bike Shop  Austell        Georgia
# 4  AW00000676  Value Added Reseller  Better Bike Shop  Austell        Georgia
#
#   Country-Region
# 0  United States
# 1  United States
# 2  United States
# 3  United States
# 4  United States
# ----------------------------------------------------------------------------------------------------
#   Postal Code         SKU                  Product  Standard Cost   Color  \
# 0       30106  BK-M82B-42   Mountain-100 Black, 42      1898.0944   Black
# 1       30106  BK-M82B-44   Mountain-100 Black, 44      1898.0944   Black
# 2       30106  BK-M82B-48   Mountain-100 Black, 48      1898.0944   Black
# 3       30106  BK-M82S-38  Mountain-100 Silver, 38      1912.1544  Silver
# 4       30106  BK-M82S-42  Mountain-100 Silver, 42      1912.1544  Silver
#
#    List Price         Model     Subcategory Category   DateKey        Date
# 0     3374.99  Mountain-100  Mountain Bikes    Bikes  20170702  2017-07-02
# 1     3374.99  Mountain-100  Mountain Bikes    Bikes  20170702  2017-07-02
# 2     3374.99  Mountain-100  Mountain Bikes    Bikes  20170702  2017-07-02
# 3     3399.99  Mountain-100  Mountain Bikes    Bikes  20170702  2017-07-02
# 4     3399.99  Mountain-100  Mountain Bikes    Bikes  20170702  2017-07-02
# ----------------------------------------------------------------------------------------------------
#   Fiscal Year Fiscal Quarter     Month     Full Date  MonthKey  \
# 0      FY2018      FY2018 Q1  2017 Jul  2017 Jul, 02    201707
# 1      FY2018      FY2018 Q1  2017 Jul  2017 Jul, 02    201707
# 2      FY2018      FY2018 Q1  2017 Jul  2017 Jul, 02    201707
# 3      FY2018      FY2018 Q1  2017 Jul  2017 Jul, 02    201707
# 4      FY2018      FY2018 Q1  2017 Jul  2017 Jul, 02    201707
#
#         Customer ID          Customer     Region        Country          Group
# 0  [Not Applicable]  [Not Applicable]  Southeast  United States  North America
# 1  [Not Applicable]  [Not Applicable]  Southeast  United States  North America
# 2  [Not Applicable]  [Not Applicable]  Southeast  United States  North America
# 3  [Not Applicable]  [Not Applicable]  Southeast  United States  North America
# 4  [Not Applicable]  [Not Applicable]  Southeast  United States  North America
# ----------------------------------------------------------------------------------------------------

# %%
# prompt: merged_df의 컬럼명에 Key 포함된 컬럼을 리스트로

key_columns = [col for col in merged_df.columns if 'Key' in col]
key_columns
# Out:
# ['SalesOrderLineKey',
#  'ResellerKey',
#  'CustomerKey',
#  'ProductKey',
#  'OrderDateKey',
#  'DueDateKey',
#  'ShipDateKey',
#  'SalesTerritoryKey',
#  'DateKey',
#  'MonthKey']

# %%
merged_df.columns
# Out:
# Index(['SalesOrderLineKey', 'ResellerKey', 'CustomerKey', 'ProductKey',
#        'OrderDateKey', 'DueDateKey', 'ShipDateKey', 'SalesTerritoryKey',
#        'Order Quantity', 'Unit Price', 'Product Standard Cost',
#        'Total Product Cost', 'Sales Amount', 'Channel', 'Sales Order',
#        'Sales Order Line', 'Reseller ID', 'Business Type', 'Reseller', 'City',
#        'State-Province', 'Country-Region', 'Postal Code', 'SKU', 'Product',
#        'Standard Cost', 'Color', 'List Price', 'Model', 'Subcategory',
#        'Category', 'DateKey', 'Date', 'Fiscal Year', 'Fiscal Quarter', 'Month',
#        'Full Date', 'MonthKey', 'Customer ID', 'Customer', 'Region', 'Country',
#        'Group'],
#       dtype='object')

# %%
matched_groups = [
    ['SalesOrderLineKey', 'Sales Order Line'],
    ['ResellerKey', 'Reseller ID'],
    ['CustomerKey', 'Customer ID'],
    ['ProductKey', 'SKU'],  # SKU = Stock Keeping Unit (제품 식별자)
    ['OrderDateKey'],
    ['DueDateKey'],
    ['ShipDateKey'],
    ['SalesTerritoryKey', 'Region'],  # 같은 맥락에서 지역 코드와 명칭일 수 있음
    ['DateKey', 'Date'],
    ['MonthKey', 'Month']
]

# %%
# prompt: matched_groups의 원소 리스트 별로 데이터프레임을 확ㅇ니하고 동일한 값을 서로 가졌는지 체크해줘

import pandas as pd
def check_group_consistency(df, group):
    """
    Checks if columns within a group in a DataFrame have consistent values.
    Assumes the first column in the group is the 'key' column and other columns
    should have the same value for each unique key.

    Args:
        df (pd.DataFrame): The input DataFrame.
        group (list): A list of column names representing the group.

    Returns:
        dict: A dictionary where keys are the key column values and values
              are dictionaries containing inconsistent columns and their
              unique values for that key. Returns an empty dictionary if all
              columns within the group are consistent for each key.
    """
    if not group or len(group) < 2:
        print(f"Group {group} has less than 2 columns. Skipping consistency check.")
        return {}

    key_col = group[0]
    other_cols = group[1:]

    if key_col not in df.columns:
        print(f"Key column '{key_col}' not found in the DataFrame. Skipping group {group}.")
        return {}

    inconsistent_data = {}

    # Group by the key column and check uniqueness of other columns
    grouped = df.groupby(key_col)
    for key_value, group_df in grouped:
        key_inconsistencies = {}
        for col in other_cols:
            if col not in group_df.columns:
                 print(f"Column '{col}' not found in the DataFrame for group {group}.")
                 continue

            unique_values = group_df[col].unique()
            if len(unique_values) > 1:
                key_inconsistencies[col] = unique_values.tolist()

        if key_inconsistencies:
            inconsistent_data[key_value] = key_inconsistencies

    return inconsistent_data

# Iterate through matched_groups and check consistency for each group in the merged_df
for group in matched_groups:
    print(f"\nChecking consistency for group: {group}")
    inconsistencies = check_group_consistency(merged_df, group)

    if not inconsistencies:
        print(f"All columns in group {group} are consistent for each unique {group[0]}.")
    else:
        print(f"Inconsistencies found in group {group}:")
        for key_value, cols_data in inconsistencies.items():
            print(f"  For {group[0]} = {key_value}:")
            for col, unique_vals in cols_data.items():
                print(f"    Column '{col}' has unique values: {unique_vals}")
# Out:
# Checking consistency for group: ['SalesOrderLineKey', 'Sales Order Line']
# All columns in group ['SalesOrderLineKey', 'Sales Order Line'] are consistent for each unique SalesOrderLineKey.
#
# Checking consistency for group: ['ResellerKey', 'Reseller ID']
# All columns in group ['ResellerKey', 'Reseller ID'] are consistent for each unique ResellerKey.
#
# Checking consistency for group: ['CustomerKey', 'Customer ID']
# All columns in group ['CustomerKey', 'Customer ID'] are consistent for each unique CustomerKey.
#
# Checking consistency for group: ['ProductKey', 'SKU']
# All columns in group ['ProductKey', 'SKU'] are consistent for each unique ProductKey.
#
# Checking consistency for group: ['OrderDateKey']
# Group ['OrderDateKey'] has less than 2 columns. Skipping consistency check.
# All columns in group ['OrderDateKey'] are consistent for each unique OrderDateKey.
#
# Checking consistency for group: ['DueDateKey']
# Group ['DueDateKey'] has less than 2 columns. Skipping consistency check.
# All columns in group ['DueDateKey'] are consistent for each unique DueDateKey.
#
# Checking consistency for group: ['ShipDateKey']
# Group ['ShipDateKey'] has less than 2 columns. Skipping consistency check.
# All columns in group ['ShipDateKey'] are consistent for each unique ShipDateKey.
#
# Checking consistency for group: ['SalesTerritoryKey', 'Region']
# All columns in group ['SalesTerritoryKey', 'Region'] are consistent for each unique SalesTerritoryKey.
#
# Checking consistency for group: ['DateKey', 'Date']
# All columns in group ['DateKey', 'Date'] are consistent for each unique DateKey.
#
# Checking consistency for group: ['MonthKey', 'Month']
# All columns in group ['MonthKey', 'Month'] are consistent for each unique MonthKey.

# %%
# prompt: merged_df에서 key_columns를 제외한 컬럼만 df로 만들어줘

df = merged_df.drop(columns=key_columns)
df.head()
# Out:
#    Order Quantity  Unit Price  Product Standard Cost  Total Product Cost  \
# 0               1    2024.994              1898.0944           1898.0944
# 1               3    2024.994              1898.0944           5694.2832
# 2               1    2024.994              1898.0944           1898.0944
# 3               1    2039.994              1912.1544           1912.1544
# 4               1    2039.994              1912.1544           1912.1544
#
#    Sales Amount   Channel Sales Order Sales Order Line Reseller ID  \
# 0      2024.994  Reseller     SO43659      SO43659 - 1  AW00000676
# 1      6074.982  Reseller     SO43659      SO43659 - 2  AW00000676
# 2      2024.994  Reseller     SO43659      SO43659 - 3  AW00000676
# 3      2039.994  Reseller     SO43659      SO43659 - 4  AW00000676
# 4      2039.994  Reseller     SO43659      SO43659 - 5  AW00000676
#
#           Business Type  ...        Date Fiscal Year Fiscal Quarter     Month  \
# 0  Value Added Reseller  ...  2017-07-02      FY2018      FY2018 Q1  2017 Jul
# 1  Value Added Reseller  ...  2017-07-02      FY2018      FY2018 Q1  2017 Jul
# 2  Value Added Reseller  ...  2017-07-02      FY2018      FY2018 Q1  2017 Jul
# 3  Value Added Reseller  ...  2017-07-02      FY2018      FY2018 Q1  2017 Jul
# 4  Value Added Reseller  ...  2017-07-02      FY2018      FY2018 Q1  2017 Jul
#
#       Full Date       Customer ID          Customer     Region        Country  \
# 0  2017 Jul, 02  [Not Applicable]  [Not Applicable]  Southeast  United States
# 1  2017 Jul, 02  [Not Applicable]  [Not Applicable]  Southeast  United States
# 2  2017 Jul, 02  [Not Applicable]  [Not Applicable]  Southeast  United States
# 3  2017 Jul, 02  [Not Applicable]  [Not Applicable]  Southeast  United States
# 4  2017 Jul, 02  [Not Applicable]  [Not Applicable]  Southeast  United States
#
#            Group
# 0  North America
# 1  North America
# 2  North America
# 3  North America
# 4  North America
#
# [5 rows x 33 columns]

# %%
summary(df)
# Out:
#                    Column DataType  MissingCount  missing_percentage  \
# 0          Order Quantity    int64             0            0.000000
# 1              Unit Price  float64             0            0.000000
# 2   Product Standard Cost  float64             0            0.000000
# 3      Total Product Cost  float64             0            0.000000
# 4            Sales Amount  float64             0            0.000000
# 5                 Channel   object             0            0.000000
# 6             Sales Order   object             0            0.000000
# 7        Sales Order Line   object             0            0.000000
# 8             Reseller ID   object             0            0.000000
# 9           Business Type   object             0            0.000000
# 10               Reseller   object             0            0.000000
# 11                   City   object             0            0.000000
# 12         State-Province   object             0            0.000000
# 13         Country-Region   object             0            0.000000
# 14            Postal Code   object             0            0.000000
# 15                    SKU   object             0            0.000000
# 16                Product   object             0            0.000000
# 17          Standard Cost  float64             0            0.000000
# 18                  Color   object         34144           28.159303
# 19             List Price  float64             0            0.000000
# 20                  Model   object             0            0.000000
# 21            Subcategory   object             0            0.000000
# 22               Category   object             0            0.000000
# 23                   Date   object             0            0.000000
# 24            Fiscal Year   object             0            0.000000
# 25         Fiscal Quarter   object             0            0.000000
# 26                  Month   object             0            0.000000
# 27              Full Date   object             0            0.000000
# 28            Customer ID   object             0            0.000000
# 29               Customer   object             0            0.000000
# 30                 Region   object             0            0.000000
# 31                Country   object             0            0.000000
# 32                  Group   object             0            0.000000
#
#     UniqueCount                                         Top7Values
# 0            41                              [1, 2, 3, 4, 5, 6, 7]
# 1           275  [4.99, 34.99, 8.99, 2.29, 469.794, 3.99, 419.4...
# 2           125  [1.8663, 13.0863, 486.7066, 0.8565, 1481.9379,...
# 3          1453  [1.8663, 13.0863, 0.8565, 1.4923, 3.3623, 6.92...
# 4          1464       [4.99, 34.99, 8.99, 2.29, 3.99, 21.98, 9.99]
# 5             2                               [Reseller, Internet]
# 6         31455  [SO51721, SO51739, SO51160, SO53465, SO47355, ...
# 7        121253  [SO75123 - 3, SO43659 - 1, SO43659 - 2, SO4365...
# 8           636  [[Not Applicable], AW00000678, AW00000054, AW0...
# 9             4  [[Not Applicable], Warehouse, Value Added Rese...
# 10          634  [[Not Applicable], Vigorous Exercise Company, ...
# 11          417  [[Not Applicable], Toronto, London, Paris, Mon...
# 12           65  [[Not Applicable], California, Ontario, Texas,...
# 13            7  [[Not Applicable], United States, Canada, Fran...
# 14          463  [[Not Applicable], M4B 1V7, M4B 1V5, V6B 3P7, ...
# 15          266  [WB-H098, CA-1098, PK-7098, TT-M928, HL-U509-B...
# 16          266  [Water Bottle - 30 oz., AWC Logo Cap, Patch Ki...
# 17          125  [1.8663, 13.0863, 486.7066, 0.8565, 1481.9379,...
# 18            8  [Black, Red, Yellow, Silver, Blue, Multi, Silv...
# 19          113   [4.99, 34.99, 8.99, 782.99, 2.29, 539.99, 53.99]
# 20          107  [Sport-100, Mountain-200, Road-650, Water Bott...
# 21           35  [Road Bikes, Tires and Tubes, Mountain Bikes, ...
# 22            4         [Accessories, Bikes, Clothing, Components]
# 23         1081  [2020-06-06, 2020-06-15, 2019-09-05, 2020-06-0...
# 24            3                           [FY2020, FY2019, FY2018]
# 25           12  [FY2020 Q2, FY2020 Q1, FY2020 Q4, FY2020 Q3, F...
# 26           36  [2020 May, 2019 Nov, 2019 Sep, 2019 Aug, 2019 ...
# 27         1081  [2020 Jun, 06, 2020 Jun, 15, 2019 Sep, 05, 202...
# 28        18485  [[Not Applicable], AW00011185, AW00011300, AW0...
# 29        18401  [[Not Applicable], Ashley Henderson, Fernando ...
# 30           10  [Southwest, Canada, Northwest, Australia, Unit...
# 31            6  [United States, Canada, Australia, United King...
# 32            3                   [North America, Europe, Pacific]

# %%
# prompt: Fiscal Year, Fiscal Quarter, Month, Customer ID, Reseller ID 는 모두 drop하라

df = df.drop(columns=['Fiscal Year', 'Fiscal Quarter', 'Month', 'Customer ID', 'Reseller ID'])
df.head()
# Out:
#    Order Quantity  Unit Price  Product Standard Cost  Total Product Cost  \
# 0               1    2024.994              1898.0944           1898.0944
# 1               3    2024.994              1898.0944           5694.2832
# 2               1    2024.994              1898.0944           1898.0944
# 3               1    2039.994              1912.1544           1912.1544
# 4               1    2039.994              1912.1544           1912.1544
#
#    Sales Amount   Channel Sales Order Sales Order Line         Business Type  \
# 0      2024.994  Reseller     SO43659      SO43659 - 1  Value Added Reseller
# 1      6074.982  Reseller     SO43659      SO43659 - 2  Value Added Reseller
# 2      2024.994  Reseller     SO43659      SO43659 - 3  Value Added Reseller
# 3      2039.994  Reseller     SO43659      SO43659 - 4  Value Added Reseller
# 4      2039.994  Reseller     SO43659      SO43659 - 5  Value Added Reseller
#
#            Reseller  ... List Price         Model     Subcategory Category  \
# 0  Better Bike Shop  ...    3374.99  Mountain-100  Mountain Bikes    Bikes
# 1  Better Bike Shop  ...    3374.99  Mountain-100  Mountain Bikes    Bikes
# 2  Better Bike Shop  ...    3374.99  Mountain-100  Mountain Bikes    Bikes
# 3  Better Bike Shop  ...    3399.99  Mountain-100  Mountain Bikes    Bikes
# 4  Better Bike Shop  ...    3399.99  Mountain-100  Mountain Bikes    Bikes
#
#          Date     Full Date          Customer     Region        Country  \
# 0  2017-07-02  2017 Jul, 02  [Not Applicable]  Southeast  United States
# 1  2017-07-02  2017 Jul, 02  [Not Applicable]  Southeast  United States
# 2  2017-07-02  2017 Jul, 02  [Not Applicable]  Southeast  United States
# 3  2017-07-02  2017 Jul, 02  [Not Applicable]  Southeast  United States
# 4  2017-07-02  2017 Jul, 02  [Not Applicable]  Southeast  United States
#
#            Group
# 0  North America
# 1  North America
# 2  North America
# 3  North America
# 4  North America
#
# [5 rows x 28 columns]

# %%
summary(df)
# Out:
#                    Column DataType  MissingCount  missing_percentage  \
# 0          Order Quantity    int64             0            0.000000
# 1              Unit Price  float64             0            0.000000
# 2   Product Standard Cost  float64             0            0.000000
# 3      Total Product Cost  float64             0            0.000000
# 4            Sales Amount  float64             0            0.000000
# 5                 Channel   object             0            0.000000
# 6             Sales Order   object             0            0.000000
# 7        Sales Order Line   object             0            0.000000
# 8           Business Type   object             0            0.000000
# 9                Reseller   object             0            0.000000
# 10                   City   object             0            0.000000
# 11         State-Province   object             0            0.000000
# 12         Country-Region   object             0            0.000000
# 13            Postal Code   object             0            0.000000
# 14                    SKU   object             0            0.000000
# 15                Product   object             0            0.000000
# 16          Standard Cost  float64             0            0.000000
# 17                  Color   object         34144           28.159303
# 18             List Price  float64             0            0.000000
# 19                  Model   object             0            0.000000
# 20            Subcategory   object             0            0.000000
# 21               Category   object             0            0.000000
# 22                   Date   object             0            0.000000
# 23              Full Date   object             0            0.000000
# 24               Customer   object             0            0.000000
# 25                 Region   object             0            0.000000
# 26                Country   object             0            0.000000
# 27                  Group   object             0            0.000000
#
#     UniqueCount                                         Top7Values
# 0            41                              [1, 2, 3, 4, 5, 6, 7]
# 1           275  [4.99, 34.99, 8.99, 2.29, 469.794, 3.99, 419.4...
# 2           125  [1.8663, 13.0863, 486.7066, 0.8565, 1481.9379,...
# 3          1453  [1.8663, 13.0863, 0.8565, 1.4923, 3.3623, 6.92...
# 4          1464       [4.99, 34.99, 8.99, 2.29, 3.99, 21.98, 9.99]
# 5             2                               [Reseller, Internet]
# 6         31455  [SO51721, SO51739, SO51160, SO53465, SO47355, ...
# 7        121253  [SO75123 - 3, SO43659 - 1, SO43659 - 2, SO4365...
# 8             4  [[Not Applicable], Warehouse, Value Added Rese...
# 9           634  [[Not Applicable], Vigorous Exercise Company, ...
# 10          417  [[Not Applicable], Toronto, London, Paris, Mon...
# 11           65  [[Not Applicable], California, Ontario, Texas,...
# 12            7  [[Not Applicable], United States, Canada, Fran...
# 13          463  [[Not Applicable], M4B 1V7, M4B 1V5, V6B 3P7, ...
# 14          266  [WB-H098, CA-1098, PK-7098, TT-M928, HL-U509-B...
# 15          266  [Water Bottle - 30 oz., AWC Logo Cap, Patch Ki...
# 16          125  [1.8663, 13.0863, 486.7066, 0.8565, 1481.9379,...
# 17            8  [Black, Red, Yellow, Silver, Blue, Multi, Silv...
# 18          113   [4.99, 34.99, 8.99, 782.99, 2.29, 539.99, 53.99]
# 19          107  [Sport-100, Mountain-200, Road-650, Water Bott...
# 20           35  [Road Bikes, Tires and Tubes, Mountain Bikes, ...
# 21            4         [Accessories, Bikes, Clothing, Components]
# 22         1081  [2020-06-06, 2020-06-15, 2019-09-05, 2020-06-0...
# 23         1081  [2020 Jun, 06, 2020 Jun, 15, 2019 Sep, 05, 202...
# 24        18401  [[Not Applicable], Ashley Henderson, Fernando ...
# 25           10  [Southwest, Canada, Northwest, Australia, Unit...
# 26            6  [United States, Canada, Australia, United King...
# 27            3                   [North America, Europe, Pacific]

# %%
# prompt: df['Date']를 날짜로 변경하라

df['Date'] = pd.to_datetime(df['Date'])

# %%
# prompt: object 형태 자료는 category로 변환

# Select columns with 'object' dtype
object_cols = df.select_dtypes(include='object').columns

# Convert selected columns to 'category' dtype
for col in object_cols:
    df[col] = df[col].astype('category')

summary(df)
# Out:
#                    Column        DataType  MissingCount  missing_percentage  \
# 0          Order Quantity           int64             0            0.000000
# 1              Unit Price         float64             0            0.000000
# 2   Product Standard Cost         float64             0            0.000000
# 3      Total Product Cost         float64             0            0.000000
# 4            Sales Amount         float64             0            0.000000
# 5                 Channel        category             0            0.000000
# 6             Sales Order        category             0            0.000000
# 7        Sales Order Line        category             0            0.000000
# 8           Business Type        category             0            0.000000
# 9                Reseller        category             0            0.000000
# 10                   City        category             0            0.000000
# 11         State-Province        category             0            0.000000
# 12         Country-Region        category             0            0.000000
# 13            Postal Code        category             0            0.000000
# 14                    SKU        category             0            0.000000
# 15                Product        category             0            0.000000
# 16          Standard Cost         float64             0            0.000000
# 17                  Color        category         34144           28.159303
# 18             List Price         float64             0            0.000000
# 19                  Model        category             0            0.000000
# 20            Subcategory        category             0            0.000000
# 21               Category        category             0            0.000000
# 22                   Date  datetime64[ns]             0            0.000000
# 23              Full Date        category             0            0.000000
# 24               Customer        category             0            0.000000
# 25                 Region        category             0            0.000000
# 26                Country        category             0            0.000000
# 27                  Group        category             0            0.000000
#
#     UniqueCount                                         Top7Values
# 0            41                              [1, 2, 3, 4, 5, 6, 7]
# 1           275  [4.99, 34.99, 8.99, 2.29, 469.794, 3.99, 419.4...
# 2           125  [1.8663, 13.0863, 486.7066, 0.8565, 1481.9379,...
# 3          1453  [1.8663, 13.0863, 0.8565, 1.4923, 3.3623, 6.92...
# 4          1464       [4.99, 34.99, 8.99, 2.29, 3.99, 21.98, 9.99]
# 5             2                               [Reseller, Internet]
# 6         31455  [SO51739, SO51721, SO51160, SO53465, SO47355, ...
# 7        121253  [SO75123 - 3, SO43659 - 1, SO43659 - 10, SO436...
# 8             4  [[Not Applicable], Warehouse, Value Added Rese...
# 9           634  [[Not Applicable], Vigorous Exercise Company, ...
# 10          417  [[Not Applicable], Toronto, London, Paris, Mon...
# 11           65  [[Not Applicable], California, Ontario, Texas,...
# 12            7  [[Not Applicable], United States, Canada, Fran...
# 13          463  [[Not Applicable], M4B 1V7, M4B 1V5, V6B 3P7, ...
# 14          266  [WB-H098, CA-1098, PK-7098, TT-M928, HL-U509-B...
# 15          266  [Water Bottle - 30 oz., AWC Logo Cap, Patch Ki...
# 16          125  [1.8663, 13.0863, 486.7066, 0.8565, 1481.9379,...
# 17            8  [Black, Red, Yellow, Silver, Blue, Multi, Silv...
# 18          113   [4.99, 34.99, 8.99, 782.99, 2.29, 539.99, 53.99]
# 19          107  [Sport-100, Mountain-200, Road-650, Water Bott...
# 20           35  [Road Bikes, Tires and Tubes, Mountain Bikes, ...
# 21            4         [Accessories, Bikes, Clothing, Components]
# 22         1081  [2020-06-06 00:00:00, 2020-06-15 00:00:00, 201...
# 23         1081  [2020 Jun, 06, 2020 Jun, 15, 2019 Sep, 05, 202...
# 24        18401  [[Not Applicable], Ashley Henderson, Fernando ...
# 25           10  [Southwest, Canada, Northwest, Australia, Unit...
# 26            6  [United States, Canada, Australia, United King...
# 27            3                   [North America, Europe, Pacific]

# %%
# prompt: [Not Applicable] 이 포함된 값은 모두 'missing'으로 변환하라

df.replace('[Not Applicable]', 'Missing', inplace=True)
summary(df)
# Out:
# /tmp/ipython-input-24-2993511463.py:3: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df.replace('[Not Applicable]', 'Missing', inplace=True)
#                    Column        DataType  MissingCount  missing_percentage  \
# 0          Order Quantity           int64             0            0.000000
# 1              Unit Price         float64             0            0.000000
# 2   Product Standard Cost         float64             0            0.000000
# 3      Total Product Cost         float64             0            0.000000
# 4            Sales Amount         float64             0            0.000000
# 5                 Channel        category             0            0.000000
# 6             Sales Order        category             0            0.000000
# 7        Sales Order Line        category             0            0.000000
# 8           Business Type        category             0            0.000000
# 9                Reseller        category             0            0.000000
# 10                   City        category             0            0.000000
# 11         State-Province        category             0            0.000000
# 12         Country-Region        category             0            0.000000
# 13            Postal Code        category             0            0.000000
# 14                    SKU        category             0            0.000000
# 15                Product        category             0            0.000000
# 16          Standard Cost         float64             0            0.000000
# 17                  Color        category         34144           28.159303
# 18             List Price         float64             0            0.000000
# 19                  Model        category             0            0.000000
# 20            Subcategory        category             0            0.000000
# 21               Category        category             0            0.000000
# 22                   Date  datetime64[ns]             0            0.000000
# 23              Full Date        category             0            0.000000
# 24               Customer        category             0            0.000000
# 25                 Region        category             0            0.000000
# 26                Country        category             0            0.000000
# 27                  Group        category             0            0.000000
#
#     UniqueCount                                         Top7Values
# 0            41                              [1, 2, 3, 4, 5, 6, 7]
# 1           275  [4.99, 34.99, 8.99, 2.29, 469.794, 3.99, 419.4...
# 2           125  [1.8663, 13.0863, 486.7066, 0.8565, 1481.9379,...
# 3          1453  [1.8663, 13.0863, 0.8565, 1.4923, 3.3623, 6.92...
# 4          1464       [4.99, 34.99, 8.99, 2.29, 3.99, 21.98, 9.99]
# 5             2                               [Reseller, Internet]
# 6         31455  [SO51739, SO51721, SO51160, SO53465, SO47355, ...
# 7        121253  [SO75123 - 3, SO43659 - 1, SO43659 - 10, SO436...
# 8             4  [Missing, Warehouse, Value Added Reseller, Spe...
# 9           634  [Missing, Vigorous Exercise Company, Larger Cy...
# 10          417  [Missing, Toronto, London, Paris, Montreal, Bu...
# 11           65  [Missing, California, Ontario, Texas, Washingt...
# 12            7  [Missing, United States, Canada, France, Unite...
# 13          463  [Missing, M4B 1V7, M4B 1V5, V6B 3P7, 98104, 75...
# 14          266  [WB-H098, CA-1098, PK-7098, TT-M928, HL-U509-B...
# 15          266  [Water Bottle - 30 oz., AWC Logo Cap, Patch Ki...
# 16          125  [1.8663, 13.0863, 486.7066, 0.8565, 1481.9379,...
# 17            8  [Black, Red, Yellow, Silver, Blue, Multi, Silv...
# 18          113   [4.99, 34.99, 8.99, 782.99, 2.29, 539.99, 53.99]
# 19          107  [Sport-100, Mountain-200, Road-650, Water Bott...
# 20           35  [Road Bikes, Tires and Tubes, Mountain Bikes, ...
# 21            4         [Accessories, Bikes, Clothing, Components]
# 22         1081  [2020-06-06 00:00:00, 2020-06-15 00:00:00, 201...
# 23         1081  [2020 Jun, 06, 2020 Jun, 15, 2019 Sep, 05, 202...
# 24        18401  [Missing, Ashley Henderson, Fernando Barnes, C...
# 25           10  [Southwest, Canada, Northwest, Australia, Unit...
# 26            6  [United States, Canada, Australia, United King...
# 27            3                   [North America, Europe, Pacific]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: /content/drive/MyDrive/데이터분석입문/data 에 df를 저장해줘

output_drive_path = '/content/drive/MyDrive/데이터분선입문/data'
os.makedirs(output_drive_path, exist_ok=True)  # 없으면 만들고 있으면 pass

# Save the final processed DataFrame to the specified drive path
df.to_csv(output_drive_path + "/processed_adventureworks_sales_data.csv", index=False)
print(f"DataFrame saved to: {output_drive_path}, 'processed_adventureworks_sales_data.csv'")
# Out:
# DataFrame saved to: /content/drive/MyDrive/데이터분선입문/data, 'processed_adventureworks_sales_data.csv'

# %% [markdown]
# ## **EDA, 시각화, RFM 분석**
