# %% [markdown]
# <a href="https://colab.research.google.com/github/ancestor9/Introduction-to-BigData-Analysis/blob/main/1%EC%A3%BC%EC%B0%A8/1%EC%A3%BC%EC%B0%A8_2%EC%B0%A8%EC%8B%9C_colab_%EC%86%8C%EA%B0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Google Colab 소개 및 사용 이유
# ## Colab 환경 설정 및 기본 UI 이해
# ## Colab에서 Python 코드 실행 실습

# %% [markdown]
# # **1. What is Big Data?**
#
# <img src ='https://image.slidesharecdn.com/amcham-big-data-hpc-200512-low-200513184135/75/big-data-and-high-performance-computing-4-2048.jpg?cb=1669423286' width=800>
#
# <img src = 'https://image.slidesharecdn.com/amcham-big-data-hpc-200512-low-200513184135/75/big-data-and-high-performance-computing-5-2048.jpg?cb=1669423286' width=800>

# %% [markdown]
# # **2. What is The three V of Big Data?**
#
# <img src='https://cdn.prod.website-files.com/64ae7b720bd1319095dd5582/66b36cfed790096a6bb2daf9_64b514acbaa2b7e02b6b75d9_three-Vs-of-big-data.jpeg'>

# %% [markdown]
# # **3. DIKW Pyramid**
#
# <img src = 'https://cdn.goconqr.com/uploads/media/image/17322876/desktop_976d9df3-92c0-41a9-939b-2fe6a63e1dcb.png'>

# %% [markdown]
# | 계층              | 질문 예시              | 핵심 키워드      |
# | --------------- | ------------------ | ----------- |
# | **Data**        | 무슨 신호가 있었나?        | 사실(fact)    |
# | **Information** | 어떤 신호등이 빨간불인가?     | 의미(meaning) |
# | **Knowledge**   | 그 신호는 나에게 어떤 의미인가? | 맥락(context) |
# | **Wisdom**      | 나는 무엇을 해야 하는가?     | 행동(action)  |

# %% [markdown]
# # **4. The Four Tyes of Data Analysis**
#
# <img src='https://almablog-media.s3.ap-south-1.amazonaws.com/Data_analysis_0ea8f061cf.png'>
