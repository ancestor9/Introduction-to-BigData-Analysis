# %% [markdown]
# <a href="https://colab.research.google.com/github/ancestor9/Introduction-to-BigData-Analysis/blob/main/1%EC%A3%BC%EC%B0%A8/1%EC%A3%BC%EC%B0%A82%EC%B0%A8%EC%8B%9C_how_to_run_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='red'> **A Crash course of Python Language Syntax**

# %% [markdown]
# *This notebook contains an excerpt from the [Whirlwind Tour of Python](http://www.oreilly.com/programming/free/a-whirlwind-tour-of-python.csp) by Jake VanderPlas; the content is available [on GitHub](https://github.com/jakevdp/WhirlwindTourOfPython).*

# %% [markdown]
# # 1. How to Run Python Code

# %% [markdown]
# - A flexible and dynamic language
# - *interpreted* rather than *compiled*. It means that it is executed line by line

# %%
id(1)
# Out:
# 10757736

# %%
a = 1
id(a)
# Out:
# 10757736

# %%
b = 1
id(a)
# Out:
# 10757736

# %%
1+1
# Out:
# 2

# %%
x=5
x*3
# Out:
# 15

# %%
x
# Out:
# 5

# %% [markdown]
# # 2. A Quick Tour of Python Language Syntax

# %% [markdown]
# ## how to terminates a Long Statement

# %%
x = 1 + 2 + 3 + 4 +\
    5 + 6 + 7 + 8
x
# Out:
# 36

# %%
x = (
    1 + 2 + 3
     + 4 +
     5 + 6 + 7 +
     8
    )
x
# Out:
# 36

# %% [markdown]
# ## Whitespace *Within* Lines Does Not Matter

# %%
x=1+2
x = 1 + 2
x             =        1    +                2

# %% [markdown]
# ## Semicolon Can Optionally Terminate a Statement

# %%
x=4;y=5
x+y
# Out:
# 9

# %% [markdown]
# ## Indentation: Whitespace Matters!

# %%
   x=5
    x
# Out:
#   File "/tmp/ipython-input-11-2733577436.py", line 2
#     x
#     ^
# IndentationError: unexpected indent

# %%
x = [1, 2, 3]
for i in x:
    print(i*10)
# Out:
# 10
# 20
# 30

# %% [markdown]
# ## Parentheses Are for Grouping or Calling
# Sometimes it can be useful to put multiple statements on a single line.

# %%
2 * (3 + 4)
# Out:
# 14

# %% [markdown]
# They can also be used to indicate that a function is being called. In the next snippet, the print() function is used to display the contents of a variable (see the sidebar). The function call is indicated by a pair of opening and closing parentheses, with the arguments to the function contained within:

# %%
print('first value:', x)
# Out:
# first value: [1, 2, 3]
