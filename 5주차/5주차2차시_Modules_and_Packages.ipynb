# %% [markdown]
# <a href="https://colab.research.google.com/github/ancestor9/Introduction-to-BigData-Analysis/blob/main/5%EC%A3%BC%EC%B0%A8/5%EC%A3%BC%EC%B0%A82%EC%B0%A8%EC%8B%9C_Modules_and_Packages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modules and Packages

# %% [markdown]
# One feature of Python that makes it useful for a wide range of tasks is the fact that it comes "batteries included" – that is, the Python standard library contains useful tools for a wide range of tasks.
# On top of this, there is a broad ecosystem of third-party tools and packages that offer more specialized functionality.
# Here we'll take a look at importing standard library modules, tools for installing third-party modules, and a description of how you can make your own modules.

# %% [markdown]
# ## **<font color='orange'>Build My Own Module(functions)**

# %%
# %%writefile utilities.py

def add(x, y):

    return x + y
def subtract(x, y):
    return x - y
# Out:
# Writing utilities.py

# %%
import utilities

# %%
utilities.add(1, 2)
# Out:
# 3

# %%
utilities.subtract(1, 2)
# Out:
# -1

# %%
from utilities import add, subtract

# %%
print("Adding 1 + 2 gives:", add(1, 2))
print("Subtracting 5 - 3 gives:", subtract(5, 3))
# Out:
# Adding 1 + 2 gives: 3
# Subtracting 5 - 3 gives: 2

# %% [markdown]
# ## Class

# %%
# %%writefile utilities_class.py

class Calculator:

    def add(x, y):

        return x + y
    def subtract(x, y):
        return x - y
# Out:
# Overwriting utilities_class.py

# %%
import utilities_class

# %%
utilities_class.Calculator.add(1, 2)
# Out:
# 3

# %%
utilities_class.Calculator.subtract(1, 2)
# Out:
# -1

# %% [markdown]
# ## **모듈은 py 파일**

# %% [markdown]
# ## Loading Modules: the ``import`` Statement
#
# For loading built-in and third-party modules, Python provides the ``import`` statement.
# There are a few ways to use the statement, which we will mention briefly here, from most recommended to least recommended.

# %% [markdown]
# ### Explicit module import
#
# Explicit import of a module preserves the module's content in a namespace.
# The namespace is then used to refer to its contents with a "``.``" between them.
# For example, here we'll import the built-in ``math`` module and compute the cosine of pi:

# %%
import math
math.cos(math.pi)
# Out:
# -1.0

# %% [markdown]
# ### Explicit module import by alias
#
# For longer module names, it's not convenient to use the full module name each time you access some element.
# For this reason, we'll commonly use the "``import ... as ...``" pattern to create a shorter alias for the namespace.
# For example, the NumPy (Numerical Python) package, a popular third-party package useful for data science, is by convention imported under the alias ``np``:

# %%
import numpy as np
np.cos(np.pi)
# Out:
# -1.0

# %% [markdown]
# ### Explicit import of module contents
#
# Sometimes rather than importing the module namespace, you would just like to import a few particular items from the module.
# This can be done with the "``from ... import ...``" pattern.
# For example, we can import just the ``cos`` function and the ``pi`` constant from the ``math`` module:

# %%
from math import cos, pi
cos(pi)
# Out:
# -1.0

# %% [markdown]
# ### Implicit import of module contents
#
# Finally, it is sometimes useful to import the entirety of the module contents into the local namespace.
# This can be done with the "``from ... import *``" pattern:

# %%
from math import *
sin(pi) ** 2 + cos(pi) ** 2
# Out:
# 1.0

# %% [markdown]
# This pattern should be used sparingly, if at all.
# The problem is that such imports can sometimes overwrite function names that you do not intend to overwrite, and the implicitness of the statement makes it difficult to determine what has changed.
#
# For example, Python has a built-in ``sum`` function that can be used for various operations:

# %%
help(sum)
# Out:
# Help on built-in function sum in module builtins:
#
# sum(...)
#     sum(iterable[, start]) -> value
#
#     Return the sum of an iterable of numbers (NOT strings) plus the value
#     of parameter 'start' (which defaults to 0).  When the iterable is
#     empty, return start.

# %% [markdown]
# We can use this to compute the sum of a sequence, starting with a certain value (here, we'll start with ``-1``):

# %%
sum(range(5), -1)
# Out:
# 9

# %% [markdown]
# Now observe what happens if we make the *exact same function call* after importing ``*`` from ``numpy``:

# %%
from numpy import *

# %%
sum(range(5), -1)
# Out:
# 10

# %% [markdown]
# The result is off by one!
# The reason for this is that the ``import *`` statement *replaces* the built-in ``sum`` function with the ``numpy.sum`` function, which has a different call signature: in the former, we're summing ``range(5)`` starting at ``-1``; in the latter, we're summing ``range(5)`` along the last axis (indicated by ``-1``).
# This is the type of situation that may arise if care is not taken when using "``import *``" – for this reason, it is best to avoid this unless you know exactly what you are doing.

# %% [markdown]
# ## Importing from Python's Standard Library
#
# Python's standard library contains many useful built-in modules, which you can read about fully in [Python's documentation](https://docs.python.org/3/library/).
# Any of these can be imported with the ``import`` statement, and then explored using the help function seen in the previous section.
# Here is an extremely incomplete list of some of the modules you might wish to explore and learn about:
#
# - ``os`` and ``sys``: Tools for interfacing with the operating system, including navigating file directory structures and executing shell commands
# - ``math`` and ``cmath``: Mathematical functions and operations on real and complex numbers
# - ``itertools``: Tools for constructing and interacting with iterators and generators
# - ``functools``: Tools that assist with functional programming
# - ``random``: Tools for generating pseudorandom numbers
# - ``pickle``: Tools for object persistence: saving objects to and loading objects from disk
# - ``json`` and ``csv``: Tools for reading JSON-formatted and CSV-formatted files.
# - ``urllib``: Tools for doing HTTP and other web requests.
#
# You can find information on these, and many more, in the Python standard library documentation: https://docs.python.org/3/library/.

# %% [markdown]
# ## Importing from Third-Party Modules
#
# One of the things that makes Python useful, especially within the world of data science, is its ecosystem of third-party modules.
# These can be imported just as the built-in modules, but first the modules must be installed on your system.
# The standard registry for such modules is the Python Package Index (*PyPI* for short), found on the Web at http://pypi.python.org/.
# For convenience, Python comes with a program called ``pip`` (a recursive acronym meaning "pip installs packages"), which will automatically fetch packages released and listed on PyPI (if you use Python version 2, ``pip`` must be installed separately).
# For example, if you'd like to install the ``supersmoother`` package that I wrote, all that is required is to type the following at the command line:
# ```
# ! pip install supersmoother
# ```
# The source code for the package will be automatically downloaded from the PyPI repository, and the package installed in the standard Python path (assuming you have permission to do so on the computer you're using).
#
# For more information about PyPI and the ``pip`` installer, refer to the documentation at http://pypi.python.org/.

# %% [markdown]
# ## **Faker 패키지**
# - https://pypi.org/project/Faker/

# %%
pip install Faker -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 21.2 MB/s eta 0:00:00

# %%
from faker import Faker
fake = Faker()

fake.name()
# Out:
# 'Antonio Morse MD'

# %%
fake.address()
# Out:
# '32350 Robles Wall Apt. 480\nNew Vickie, WV 56613'

# %%
fake.text()
# Out:
# 'Either hit sport professional create wind interview. Difficult Republican sort fund choice sit.\nType happy security respond see member decade. Race system staff one view.'

# %%
# prompt: fake를 사용하여 이름, 주소, 전화번호, 직업, 이메일 등을 key로 하는 사전형데이터 100개를 무작위로 생성해줘

fake = Faker('ko_KR')

data = []
for _ in range(100):
    person_data = {
        '이름': fake.name(),
        '주소': fake.address(),
        '전화번호': fake.phone_number(),
        '직업': fake.job(),
        '이메일': fake.email()
    }
    data.append(person_data)

# Optional: Print the first few entries to verify
for i in range(5):
    print(data[i])
    print("-" * 20)
# Out:
# {'이름': '김민수', '주소': '강원도 고양시 백제고분2길 677-53 (광수김마을)', '전화번호': '054-244-9155', '직업': '텔레마케터', '이메일': 'hyeonjeonggim@example.com'}
# --------------------
# {'이름': '박미경', '주소': '경기도 속초시 서초중앙로 219-39', '전화번호': '062-513-0897', '직업': '가수 및 성악가', '이메일': 'yeongceolca@example.net'}
# --------------------
# {'이름': '김정숙', '주소': '경기도 성남시 중원구 양재천6거리 416-36 (준서심김리)', '전화번호': '070-4868-3667', '직업': '오락시설 서비스원', '이메일': 'jangsumin@example.com'}
# --------------------
# {'이름': '이미숙', '주소': '대구광역시 중구 논현734로 483 (지은이리)', '전화번호': '041-143-9207', '직업': '버스 운전원', '이메일': 'hongjeongsun@example.org'}
# --------------------
# {'이름': '김성수', '주소': '대전광역시 중랑구 학동길 854-95 (정식이읍)', '전화번호': '044-045-8728', '직업': '기획 및 마케팅 사무원', '이메일': 'gryu@example.org'}
# --------------------

# %%
data
# Out:
# [{'이름': '김민수',
#   '주소': '강원도 고양시 백제고분2길 677-53 (광수김마을)',
#   '전화번호': '054-244-9155',
#   '직업': '텔레마케터',
#   '이메일': 'hyeonjeonggim@example.com'},
#  {'이름': '박미경',
#   '주소': '경기도 속초시 서초중앙로 219-39',
#   '전화번호': '062-513-0897',
#   '직업': '가수 및 성악가',
#   '이메일': 'yeongceolca@example.net'},
#  {'이름': '김정숙',
#   '주소': '경기도 성남시 중원구 양재천6거리 416-36 (준서심김리)',
#   '전화번호': '070-4868-3667',
#   '직업': '오락시설 서비스원',
#   '이메일': 'jangsumin@example.com'},
#  {'이름': '이미숙',
#   '주소': '대구광역시 중구 논현734로 483 (지은이리)',
#   '전화번호': '041-143-9207',
#   '직업': '버스 운전원',
#   '이메일': 'hongjeongsun@example.org'},
#  {'이름': '김성수',
#   '주소': '대전광역시 중랑구 학동길 854-95 (정식이읍)',
#   '전화번호': '044-045-8728',
#   '직업': '기획 및 마케팅 사무원',
#   '이메일': 'gryu@example.org'},
#  {'이름': '김정남',
#   '주소': '부산광역시 구로구 삼성0가 150 (예은최김리)',
#   '전화번호': '062-797-1262',
#   '직업': '통역가',
#   '이메일': 'ni@example.org'},
#  {'이름': '박은영',
#   '주소': '강원도 시흥시 역삼길 207 (현정오리)',
#   '전화번호': '053-875-3470',
#   '직업': '경영지원 관리자',
#   '이메일': 'sujini@example.com'},
#  {'이름': '진영환',
#   '주소': '세종특별자치시 동대문구 영동대가 407',
#   '전화번호': '033-378-1381',
#   '직업': '장학관/연구관 및 교육 관련 전문가',
#   '이메일': 'mijeong50@example.net'},
#  {'이름': '신영길',
#   '주소': '전라남도 성남시 중원구 도산대3거리 지하544',
#   '전화번호': '041-515-7177',
#   '직업': '판금기 조작원',
#   '이메일': 'yejun57@example.org'},
#  {'이름': '김서연',
#   '주소': '경상남도 하남시 봉은사거리 지하7',
#   '전화번호': '043-543-2772',
#   '직업': '변리사',
#   '이메일': 'ijeonghyi@example.net'},
#  {'이름': '노예지',
#   '주소': '울산광역시 마포구 가락3거리 지하189 (영호김읍)',
#   '전화번호': '042-619-7248',
#   '직업': '숙박시설 서비스원',
#   '이메일': 'jaehyeon93@example.com'},
#  {'이름': '배우진',
#   '주소': '경상남도 동해시 개포5로 740 (경수박문동)',
#   '전화번호': '051-897-2177',
#   '직업': '용접기 조작원',
#   '이메일': 'ijo@example.org'},
#  {'이름': '이명자',
#   '주소': '전라북도 안양시 학동6로 23',
#   '전화번호': '044-623-8329',
#   '직업': '웨이터',
#   '이메일': 'seoyeon48@example.net'},
#  {'이름': '최도현',
#   '주소': '전라북도 안산시 압구정로 953-25 (옥자이리)',
#   '전화번호': '032-305-7361',
#   '직업': '기타 판매관련 단순 종사원',
#   '이메일': 'namyejin@example.net'},
#  {'이름': '김진우',
#   '주소': '대전광역시 노원구 학동가 281 (영수강면)',
#   '전화번호': '043-858-3012',
#   '직업': '소방관',
#   '이메일': 'ihyejin@example.org'},
#  {'이름': '홍현지',
#   '주소': '울산광역시 중랑구 서초중앙길 865',
#   '전화번호': '054-748-7471',
#   '직업': '화학공학 기술자 및 연구원',
#   '이메일': 'pgim@example.net'},
#  {'이름': '오현우',
#   '주소': '서울특별시 동작구 역삼9로 387 (순옥최동)',
#   '전화번호': '061-964-2086',
#   '직업': '임산물채취 및 기타 임업 관련 종사원',
#   '이메일': 'yeonghyi79@example.net'},
#  {'이름': '이지혜',
#   '주소': '강원도 태안군 양재천가 735-26 (지영김동)',
#   '전화번호': '019-206-0730',
#   '직업': '가수 및 성악가',
#   '이메일': 'yeongmihan@example.org'},
#  {'이름': '남정호',
#   '주소': '울산광역시 은평구 학동49길 689',
#   '전화번호': '032-394-6460',
#   '직업': '한복 제조원',
#   '이메일': 'yeongsun05@example.com'},
#  {'이름': '최지원',
#   '주소': '제주특별자치도 용인시 백제고분35가 114-18 (현주구장동)',
#   '전화번호': '017-456-4870',
#   '직업': '직조기 및 편직기 조작원',
#   '이메일': 'jeongsugji@example.net'},
#  {'이름': '우재호',
#   '주소': '광주광역시 강서구 서초대121가 74 (예지김백면)',
#   '전화번호': '016-191-9104',
#   '직업': '양장 및 양복 제조원',
#   '이메일': 'ijiu@example.com'},
#  {'이름': '강지혜',
#   '주소': '인천광역시 광진구 언주45로 469',
#   '전화번호': '062-816-0431',
#   '직업': '영양사',
#   '이메일': 'ibyeongceol@example.net'},
#  {'이름': '이정숙',
#   '주소': '부산광역시 강동구 석촌호수438거리 860',
#   '전화번호': '019-611-1522',
#   '직업': '기타 건설/전기 및 생산 관련 관리자',
#   '이메일': 'pgim@example.org'},
#  {'이름': '최성훈',
#   '주소': '경기도 서산시 언주8로 71-53',
#   '전화번호': '010-2184-8816',
#   '직업': '배관 세정원 및 방역원',
#   '이메일': 'suminbaeg@example.com'},
#  {'이름': '최성민',
#   '주소': '제주특별자치도 횡성군 가락로 199-67',
#   '전화번호': '018-110-4576',
#   '직업': '택배원',
#   '이메일': 'jeonbyeongceol@example.com'},
#  {'이름': '박영미',
#   '주소': '충청남도 청주시 흥덕구 개포거리 440 (상호김양리)',
#   '전화번호': '019-614-3637',
#   '직업': '기자 및 논설위원',
#   '이메일': 'igim@example.com'},
#  {'이름': '김준영',
#   '주소': '전라북도 단양군 언주길 582 (준서김황면)',
#   '전화번호': '054-475-1649',
#   '직업': '화물차 및 특수차 운전원',
#   '이메일': 'thwang@example.org'},
#  {'이름': '김춘자',
#   '주소': '울산광역시 동구 봉은사길 567 (예진문읍)',
#   '전화번호': '063-902-1665',
#   '직업': '금속가공 기계조작원',
#   '이메일': 'yeonghobag@example.net'},
#  {'이름': '이채원',
#   '주소': '제주특별자치도 안양시 동안구 삼성7길 217 (수진장읍)',
#   '전화번호': '044-036-5912',
#   '직업': '제품 및 광고 영업원',
#   '이메일': 'hyeonjeong47@example.net'},
#  {'이름': '김현지',
#   '주소': '전라남도 청주시 서원구 백제고분거리 973-26 (숙자이읍)',
#   '전화번호': '032-002-0303',
#   '직업': '웨이터',
#   '이메일': 'geonu62@example.net'},
#  {'이름': '백건우',
#   '주소': '경상남도 용인시 학동로 794 (정식배동)',
#   '전화번호': '052-837-4834',
#   '직업': '농업용 및 기타 기계장비 설치 및 정비원',
#   '이메일': 'qseong@example.net'},
#  {'이름': '서성훈',
#   '주소': '충청북도 성남시 중원구 양재천79길 122 (영길김마을)',
#   '전화번호': '061-700-3367',
#   '직업': '기타 의복 제조원',
#   '이메일': 'cgang@example.org'},
#  {'이름': '손예진',
#   '주소': '부산광역시 관악구 언주로 35-45 (현주유이면)',
#   '전화번호': '052-147-2285',
#   '직업': '건설자재 시험원',
#   '이메일': 'yejinmin@example.com'},
#  {'이름': '박춘자',
#   '주소': '전라남도 연천군 학동75가 275-4 (선영최동)',
#   '전화번호': '051-886-8569',
#   '직업': '기술 영업원',
#   '이메일': 'josugja@example.com'},
#  {'이름': '김광수',
#   '주소': '경상남도 강릉시 테헤란길 195-30 (성수김리)',
#   '전화번호': '063-307-1213',
#   '직업': '사서 및 기록물관리사',
#   '이메일': 'songjunho@example.org'},
#  {'이름': '김정숙',
#   '주소': '전라남도 속초시 반포대78가 102-3 (지후김이리)',
#   '전화번호': '032-796-9960',
#   '직업': '기술 영업원',
#   '이메일': 'caeweon16@example.com'},
#  {'이름': '김수진',
#   '주소': '경상북도 아산시 봉은사길 848',
#   '전화번호': '031-227-5267',
#   '직업': '만화가 및 만화영화 작가',
#   '이메일': 'lgim@example.com'},
#  {'이름': '박성훈',
#   '주소': '울산광역시 영등포구 개포로 5-22',
#   '전화번호': '054-147-5525',
#   '직업': '농림어업관련 단순 종사원',
#   '이메일': 'sbag@example.com'},
#  {'이름': '노은경',
#   '주소': '인천광역시 중랑구 봉은사21길 963-35',
#   '전화번호': '02-1631-7911',
#   '직업': '건축 석공',
#   '이메일': 'dohyeongim@example.com'},
#  {'이름': '김영희',
#   '주소': '대구광역시 용산구 역삼로 지하50',
#   '전화번호': '063-227-3745',
#   '직업': '사회복지사',
#   '이메일': 'seojun16@example.com'},
#  {'이름': '김영수',
#   '주소': '경상남도 하남시 서초중앙거리 563-81 (영철박최리)',
#   '전화번호': '055-608-5343',
#   '직업': '피부미용 및 체형관리사',
#   '이메일': 'jihun19@example.com'},
#  {'이름': '김은서',
#   '주소': '강원도 정선군 봉은사8가 613-27 (영길허리)',
#   '전화번호': '019-923-7188',
#   '직업': '일반 의사',
#   '이메일': 'minjibag@example.org'},
#  {'이름': '이혜진',
#   '주소': '서울특별시 남구 오금로 747-73',
#   '전화번호': '010-4049-0559',
#   '직업': '기타 식품가공관련 종사원',
#   '이메일': 'yunseobag@example.com'},
#  {'이름': '서상현',
#   '주소': '전라북도 구리시 봉은사37거리 881 (정훈김동)',
#   '전화번호': '055-126-9534',
#   '직업': '사진기자 및 사진가',
#   '이메일': 'seoyun72@example.net'},
#  {'이름': '김유진',
#   '주소': '전라남도 청주시 청원구 개포2길 지하911 (은영김면)',
#   '전화번호': '017-654-2411',
#   '직업': '상품기획 전문가',
#   '이메일': 'jaehyeonim@example.net'},
#  {'이름': '오예원',
#   '주소': '서울특별시 마포구 서초대가 374 (중수박권읍)',
#   '전화번호': '010-8897-0089',
#   '직업': '손해사정인',
#   '이메일': 'junhogim@example.net'},
#  {'이름': '박성수',
#   '주소': '전라북도 속초시 양재천50길 565-97 (성수강손리)',
#   '전화번호': '016-355-2302',
#   '직업': '치과기공사',
#   '이메일': 'seoyeonhwang@example.com'},
#  {'이름': '오영수',
#   '주소': '강원도 옥천군 백제고분06로 973-16 (경희최읍)',
#   '전화번호': '02-7106-5564',
#   '직업': '상/하수도 처리장치 조작원',
#   '이메일': 'sujin66@example.com'},
#  {'이름': '남하은',
#   '주소': '강원도 수원시 양재천389길 737-52',
#   '전화번호': '054-481-7430',
#   '직업': '가구조립원',
#   '이메일': 'seongminjang@example.net'},
#  {'이름': '김미정',
#   '주소': '서울특별시 구로구 석촌호수길 651-45 (미정이서면)',
#   '전화번호': '061-542-7435',
#   '직업': '경기심판 및 경기기록원',
#   '이메일': 'jiweon23@example.org'},
#  {'이름': '권영철',
#   '주소': '경상남도 청주시 상당구 테헤란길 973 (건우서리)',
#   '전화번호': '042-466-2362',
#   '직업': '발전 및 배전장치 조작원',
#   '이메일': 'jhong@example.net'},
#  {'이름': '홍중수',
#   '주소': '대구광역시 성동구 양재천거리 116 (영숙오마을)',
#   '전화번호': '051-306-8684',
#   '직업': '기술 및 기능계 강사',
#   '이메일': 'sunjabag@example.com'},
#  {'이름': '김예진',
#   '주소': '충청북도 양양군 영동대길 829-23 (지우이읍)',
#   '전화번호': '042-666-5244',
#   '직업': '조경 기술자',
#   '이메일': 'yeonghyii@example.com'},
#  {'이름': '박유진',
#   '주소': '제주특별자치도 공주시 테헤란04가 910 (상철문마을)',
#   '전화번호': '042-285-1885',
#   '직업': '보험 심사원 및 사무원',
#   '이메일': 'borambag@example.net'},
#  {'이름': '배은주',
#   '주소': '전라남도 횡성군 서초중앙로 111 (현숙손박리)',
#   '전화번호': '055-374-3701',
#   '직업': '통신/방송 및 인터넷 케이블 설치 및 수리원',
#   '이메일': 'lyun@example.net'},
#  {'이름': '한현우',
#   '주소': '대구광역시 강동구 백제고분5로 438 (명자하면)',
#   '전화번호': '053-771-5900',
#   '직업': '자동차 조립원',
#   '이메일': 'gimyeeun@example.org'},
#  {'이름': '이성훈',
#   '주소': '부산광역시 관악구 양재천08가 434',
#   '전화번호': '062-175-4995',
#   '직업': '금속가공 기계조작원',
#   '이메일': 'jeonghyi04@example.org'},
#  {'이름': '지명자',
#   '주소': '충청북도 안산시 상록구 테헤란2로 474-52',
#   '전화번호': '055-883-3118',
#   '직업': '웹 및 멀티미디어 기획자',
#   '이메일': 'seonghogim@example.org'},
#  {'이름': '노정수',
#   '주소': '경기도 김포시 언주64로 416',
#   '전화번호': '063-563-3187',
#   '직업': '자동차 영업원',
#   '이메일': 'gimsumin@example.org'},
#  {'이름': '최상호',
#   '주소': '광주광역시 광진구 서초대거리 지하832 (영일윤읍)',
#   '전화번호': '064-724-8074',
#   '직업': '큐레이터 및 문화재 보존원',
#   '이메일': 'jeongung35@example.net'},
#  {'이름': '이재호',
#   '주소': '부산광역시 종로구 잠실가 152',
#   '전화번호': '031-671-3432',
#   '직업': '제관원',
#   '이메일': 'haeungim@example.org'},
#  {'이름': '김상철',
#   '주소': '광주광역시 도봉구 봉은사길 67',
#   '전화번호': '052-063-0314',
#   '직업': '경기심판 및 경기기록원',
#   '이메일': 'eunyeong22@example.com'},
#  {'이름': '배광수',
#   '주소': '충청북도 이천시 삼성길 126',
#   '전화번호': '070-1478-1207',
#   '직업': '텔레마케터',
#   '이메일': 'gimjeongsig@example.com'},
#  {'이름': '최정식',
#   '주소': '제주특별자치도 삼척시 서초중앙19길 147 (선영최면)',
#   '전화번호': '016-187-9056',
#   '직업': '장학관/연구관 및 교육 관련 전문가',
#   '이메일': 'eunyeong21@example.com'},
#  {'이름': '주순옥',
#   '주소': '강원도 광주시 압구정로 187-99',
#   '전화번호': '02-5370-3545',
#   '직업': '데이터베이스 개발자',
#   '이메일': 'mcoe@example.com'},
#  {'이름': '강영길',
#   '주소': '전라북도 태안군 강남대95길 388-24 (준서이읍)',
#   '전화번호': '052-829-2521',
#   '직업': '조사 전문가',
#   '이메일': 'yeongsig57@example.com'},
#  {'이름': '장예준',
#   '주소': '전라남도 아산시 잠실82거리 391 (지훈문정동)',
#   '전화번호': '042-324-3451',
#   '직업': '가전제품 설치 및 수리원',
#   '이메일': 'ihwang@example.net'},
#  {'이름': '홍성수',
#   '주소': '대구광역시 용산구 잠실026거리 지하48 (준서양리)',
#   '전화번호': '017-690-2511',
#   '직업': '과실 및 채소 관련 기계조작원',
#   '이메일': 'icunja@example.org'},
#  {'이름': '김정식',
#   '주소': '인천광역시 강서구 강남대8길 920 (수민강이읍)',
#   '전화번호': '044-119-6530',
#   '직업': '산업안전 및 위험 관리원',
#   '이메일': 'sunog34@example.net'},
#  {'이름': '이도윤',
#   '주소': '대구광역시 동구 역삼길 983-91',
#   '전화번호': '02-9981-8713',
#   '직업': '경량 철골공',
#   '이메일': 'coegyeongsug@example.net'},
#  {'이름': '박예진',
#   '주소': '울산광역시 동대문구 강남대가 794 (현지백읍)',
#   '전화번호': '017-298-7819',
#   '직업': '판금기 조작원',
#   '이메일': 'gimjinu@example.com'},
#  {'이름': '진현지',
#   '주소': '경상북도 안산시 상록구 언주0가 637-90',
#   '전화번호': '053-821-4354',
#   '직업': '소년보호관 및 교도관',
#   '이메일': 'seongho30@example.net'},
#  {'이름': '김성진',
#   '주소': '충청북도 청주시 흥덕구 반포대길 615 (미정김나읍)',
#   '전화번호': '051-040-5921',
#   '직업': '모피 및 가죽의복 제조원',
#   '이메일': 'myeongja64@example.net'},
#  {'이름': '이미영',
#   '주소': '광주광역시 도봉구 영동대8거리 734-42',
#   '전화번호': '044-789-8804',
#   '직업': '초등학교 교사',
#   '이메일': 'yujeongho@example.com'},
#  {'이름': '박진호',
#   '주소': '울산광역시 마포구 오금거리 44-60 (상철안동)',
#   '전화번호': '016-935-7379',
#   '직업': '기타 직물 및 신발 관련 기계조작원 및 조립원',
#   '이메일': 'ihyeonu@example.net'},
#  {'이름': '서수민',
#   '주소': '전라남도 제천시 석촌호수가 911 (경숙이동)',
#   '전화번호': '064-783-8532',
#   '직업': '보험 및 금융 관리자',
#   '이메일': 'vgim@example.com'},
#  {'이름': '이수빈',
#   '주소': '충청북도 부천시 오정구 봉은사184로 지하83',
#   '전화번호': '016-901-0911',
#   '직업': '매표원 및 복권 판매원',
#   '이메일': 'yeonggilgim@example.org'},
#  {'이름': '김미영',
#   '주소': '경상북도 정선군 백제고분가 616 (정숙안리)',
#   '전화번호': '051-415-0155',
#   '직업': '결혼 상담원 및 웨딩플래너',
#   '이메일': 'obag@example.net'},
#  {'이름': '이선영',
#   '주소': '전라북도 증평군 봉은사307로 34 (시우이배마을)',
#   '전화번호': '052-953-3161',
#   '직업': '정부행정 관리자',
#   '이메일': 'hyejino@example.net'},
#  {'이름': '최병철',
#   '주소': '울산광역시 동작구 논현3거리 937-7',
#   '전화번호': '017-480-7376',
#   '직업': '아나운서 및 리포터',
#   '이메일': 'gwageunyeong@example.com'},
#  {'이름': '박민서',
#   '주소': '대전광역시 종로구 강남대로 908-47',
#   '전화번호': '016-640-4289',
#   '직업': '웨이터',
#   '이메일': 'ihyeonjeong@example.net'},
#  {'이름': '이은영',
#   '주소': '부산광역시 노원구 서초대253로 23 (서연문서마을)',
#   '전화번호': '017-043-2611',
#   '직업': '철도 기관차 및 전동차 정비원',
#   '이메일': 'gimjaeho@example.net'},
#  {'이름': '김건우',
#   '주소': '서울특별시 남구 역삼76거리 지하85',
#   '전화번호': '054-195-4411',
#   '직업': '가스/에너지 기술자 및 연구원',
#   '이메일': 'jieuncoe@example.net'},
#  {'이름': '강동현',
#   '주소': '경기도 당진시 석촌호수97길 447 (재호이백면)',
#   '전화번호': '042-652-4220',
#   '직업': '컴퓨터 하드웨어 기술자 및 연구원',
#   '이메일': 'iyeongmi@example.net'},
#  {'이름': '김상호',
#   '주소': '경상북도 평택시 석촌호수길 150',
#   '전화번호': '016-967-4762',
#   '직업': '기타 행정 및 경영지원 관리자',
#   '이메일': 'mgim@example.net'},
#  {'이름': '박춘자',
#   '주소': '충청남도 여주시 개포29거리 406-92 (영일박윤동)',
#   '전화번호': '016-609-7345',
#   '직업': '전자공학 기술자 및 연구원',
#   '이메일': 'sunog47@example.net'},
#  {'이름': '김혜진',
#   '주소': '광주광역시 강남구 개포길 82',
#   '전화번호': '064-705-3952',
#   '직업': '인문과학 연구원',
#   '이메일': 'munseungmin@example.org'},
#  {'이름': '김성호',
#   '주소': '광주광역시 동구 서초중앙거리 598-35 (동현조이마을)',
#   '전화번호': '061-529-4656',
#   '직업': '악기제조 및 조율사',
#   '이메일': 'gangjunho@example.com'},
#  {'이름': '김영진',
#   '주소': '세종특별자치시 구로구 개포로 792-22',
#   '전화번호': '063-514-6982',
#   '직업': '웨이터',
#   '이메일': 'migyeongbag@example.net'},
#  {'이름': '홍은지',
#   '주소': '서울특별시 중랑구 오금30가 741',
#   '전화번호': '017-270-8760',
#   '직업': '투자 및 신용 분석가',
#   '이메일': 'anogja@example.org'},
#  {'이름': '박민재',
#   '주소': '부산광역시 용산구 양재천거리 지하627',
#   '전화번호': '02-1782-6951',
#   '직업': '물품이동 장비 조작원',
#   '이메일': 'minjaeno@example.net'},
#  {'이름': '이영자',
#   '주소': '울산광역시 동구 언주493거리 946 (하윤김리)',
#   '전화번호': '016-804-0479',
#   '직업': '스포츠 및 레크레이션 강사',
#   '이메일': 'si@example.org'},
#  {'이름': '이중수',
#   '주소': '대전광역시 영등포구 오금가 769',
#   '전화번호': '042-732-8749',
#   '직업': '방사선사',
#   '이메일': 'seunghyeonbag@example.com'},
#  {'이름': '김영수',
#   '주소': '대전광역시 광진구 학동642길 96 (명자김면)',
#   '전화번호': '041-479-7582',
#   '직업': '기타 행정 및 경영지원 관리자',
#   '이메일': 'jeongho51@example.net'},
#  {'이름': '정민서',
#   '주소': '서울특별시 서구 강남대가 246-95 (상철성김마을)',
#   '전화번호': '054-276-0486',
#   '직업': '자재관리 사무원',
#   '이메일': 'mijeonghan@example.org'},
#  {'이름': '서준영',
#   '주소': '경상남도 부천시 원미구 양재천가 384-1 (예지윤이동)',
#   '전화번호': '064-728-5464',
#   '직업': '통신서비스판매원',
#   '이메일': 'jeongsunryu@example.net'},
#  {'이름': '박민준',
#   '주소': '서울특별시 서대문구 강남대692길 274 (현지김나면)',
#   '전화번호': '010-9734-3486',
#   '직업': '판금원',
#   '이메일': 'areumi@example.org'},
#  {'이름': '김영수',
#   '주소': '광주광역시 동작구 잠실4거리 719-43',
#   '전화번호': '070-3516-6479',
#   '직업': '방수공',
#   '이메일': 'yeongil86@example.net'},
#  {'이름': '조민재',
#   '주소': '인천광역시 중구 언주거리 931 (민준최면)',
#   '전화번호': '061-101-8779',
#   '직업': '섬유제조 기계조작원',
#   '이메일': 'jinho60@example.com'},
#  {'이름': '한은지',
#   '주소': '광주광역시 북구 역삼거리 383 (정순김김마을)',
#   '전화번호': '011-194-9028',
#   '직업': '김치 및 밑반찬 제조 종사원',
#   '이메일': 'jeongung74@example.org'}]
