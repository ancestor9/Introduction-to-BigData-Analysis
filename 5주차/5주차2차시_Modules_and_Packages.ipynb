# %% [markdown]
# <a href="https://colab.research.google.com/github/ancestor9/Introduction-to-BigData-Analysis/blob/main/5%EC%A3%BC%EC%B0%A8/5%EC%A3%BC%EC%B0%A82%EC%B0%A8%EC%8B%9C_Modules_and_Packages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modules and Packages

# %% [markdown]
# One feature of Python that makes it useful for a wide range of tasks is the fact that it comes "batteries included" – that is, the Python standard library contains useful tools for a wide range of tasks.
# On top of this, there is a broad ecosystem of third-party tools and packages that offer more specialized functionality.
# Here we'll take a look at importing standard library modules, tools for installing third-party modules, and a description of how you can make your own modules.

# %% [markdown]
# ## **<font color='orange'>Build My Own Module(functions)**

# %%
# %%writefile utilities.py

def add(x, y):

    return x + y
def subtract(x, y):
    return x - y
# Out:
# Writing utilities.py

# %%
import utilities

# %%
utilities.add(1, 2)
# Out:
# 3

# %%
utilities.subtract(1, 2)
# Out:
# -1

# %%
from utilities import add, subtract

# %%
print("Adding 1 + 2 gives:", add(1, 2))
print("Subtracting 5 - 3 gives:", subtract(5, 3))
# Out:
# Adding 1 + 2 gives: 3
# Subtracting 5 - 3 gives: 2

# %% [markdown]
# ## Class

# %%
# %%writefile utilities_class.py

class Calculator:

    def add(x, y):

        return x + y
    def subtract(x, y):
        return x - y
# Out:
# Overwriting utilities_class.py

# %%
import utilities_class

# %%
utilities_class.Calculator.add(1, 2)
# Out:
# 3

# %%
utilities_class.Calculator.subtract(1, 2)
# Out:
# -1

# %% [markdown]
# ## **모듈은 py 파일**

# %% [markdown]
# ## Loading Modules: the ``import`` Statement
#
# For loading built-in and third-party modules, Python provides the ``import`` statement.
# There are a few ways to use the statement, which we will mention briefly here, from most recommended to least recommended.

# %% [markdown]
# ### Explicit module import
#
# Explicit import of a module preserves the module's content in a namespace.
# The namespace is then used to refer to its contents with a "``.``" between them.
# For example, here we'll import the built-in ``math`` module and compute the cosine of pi:

# %%
import math
math.cos(math.pi)
# Out:
# -1.0

# %% [markdown]
# ### Explicit module import by alias
#
# For longer module names, it's not convenient to use the full module name each time you access some element.
# For this reason, we'll commonly use the "``import ... as ...``" pattern to create a shorter alias for the namespace.
# For example, the NumPy (Numerical Python) package, a popular third-party package useful for data science, is by convention imported under the alias ``np``:

# %%
import numpy as np
np.cos(np.pi)
# Out:
# -1.0

# %% [markdown]
# ### Explicit import of module contents
#
# Sometimes rather than importing the module namespace, you would just like to import a few particular items from the module.
# This can be done with the "``from ... import ...``" pattern.
# For example, we can import just the ``cos`` function and the ``pi`` constant from the ``math`` module:

# %%
from math import cos, pi
cos(pi)
# Out:
# -1.0

# %% [markdown]
# ### Implicit import of module contents
#
# Finally, it is sometimes useful to import the entirety of the module contents into the local namespace.
# This can be done with the "``from ... import *``" pattern:

# %%
from math import *
sin(pi) ** 2 + cos(pi) ** 2
# Out:
# 1.0

# %% [markdown]
# This pattern should be used sparingly, if at all.
# The problem is that such imports can sometimes overwrite function names that you do not intend to overwrite, and the implicitness of the statement makes it difficult to determine what has changed.
#
# For example, Python has a built-in ``sum`` function that can be used for various operations:

# %%
help(sum)
# Out:
# Help on built-in function sum in module builtins:
#
# sum(...)
#     sum(iterable[, start]) -> value
#
#     Return the sum of an iterable of numbers (NOT strings) plus the value
#     of parameter 'start' (which defaults to 0).  When the iterable is
#     empty, return start.

# %% [markdown]
# We can use this to compute the sum of a sequence, starting with a certain value (here, we'll start with ``-1``):

# %%
sum(range(5), -1)
# Out:
# 9

# %% [markdown]
# Now observe what happens if we make the *exact same function call* after importing ``*`` from ``numpy``:

# %%
from numpy import *

# %%
sum(range(5), -1)
# Out:
# 10

# %% [markdown]
# The result is off by one!
# The reason for this is that the ``import *`` statement *replaces* the built-in ``sum`` function with the ``numpy.sum`` function, which has a different call signature: in the former, we're summing ``range(5)`` starting at ``-1``; in the latter, we're summing ``range(5)`` along the last axis (indicated by ``-1``).
# This is the type of situation that may arise if care is not taken when using "``import *``" – for this reason, it is best to avoid this unless you know exactly what you are doing.

# %% [markdown]
# ## Importing from Python's Standard Library
#
# Python's standard library contains many useful built-in modules, which you can read about fully in [Python's documentation](https://docs.python.org/3/library/).
# Any of these can be imported with the ``import`` statement, and then explored using the help function seen in the previous section.
# Here is an extremely incomplete list of some of the modules you might wish to explore and learn about:
#
# - ``os`` and ``sys``: Tools for interfacing with the operating system, including navigating file directory structures and executing shell commands
# - ``math`` and ``cmath``: Mathematical functions and operations on real and complex numbers
# - ``itertools``: Tools for constructing and interacting with iterators and generators
# - ``functools``: Tools that assist with functional programming
# - ``random``: Tools for generating pseudorandom numbers
# - ``pickle``: Tools for object persistence: saving objects to and loading objects from disk
# - ``json`` and ``csv``: Tools for reading JSON-formatted and CSV-formatted files.
# - ``urllib``: Tools for doing HTTP and other web requests.
#
# You can find information on these, and many more, in the Python standard library documentation: https://docs.python.org/3/library/.

# %% [markdown]
# ## Importing from Third-Party Modules
#
# One of the things that makes Python useful, especially within the world of data science, is its ecosystem of third-party modules.
# These can be imported just as the built-in modules, but first the modules must be installed on your system.
# The standard registry for such modules is the Python Package Index (*PyPI* for short), found on the Web at http://pypi.python.org/.
# For convenience, Python comes with a program called ``pip`` (a recursive acronym meaning "pip installs packages"), which will automatically fetch packages released and listed on PyPI (if you use Python version 2, ``pip`` must be installed separately).
# For example, if you'd like to install the ``supersmoother`` package that I wrote, all that is required is to type the following at the command line:
# ```
# ! pip install supersmoother
# ```
# The source code for the package will be automatically downloaded from the PyPI repository, and the package installed in the standard Python path (assuming you have permission to do so on the computer you're using).
#
# For more information about PyPI and the ``pip`` installer, refer to the documentation at http://pypi.python.org/.

# %% [markdown]
# ## **Faker 패키지**
# - https://pypi.org/project/Faker/

# %%
pip install Faker -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 21.2 MB/s eta 0:00:00

# %%
from faker import Faker
fake = Faker()

fake.name()
# Out:
# 'Antonio Morse MD'

# %%
fake.address()
# Out:
# '32350 Robles Wall Apt. 480\nNew Vickie, WV 56613'

# %%
fake.text()
# Out:
# 'Either hit sport professional create wind interview. Difficult Republican sort fund choice sit.\nType happy security respond see member decade. Race system staff one view.'

# %%
# prompt: fake를 사용하여 이름, 주소, 전화번호, 직업, 이메일 등을 key로 하는 사전형데이터 100개를 무작위로 생성해줘

fake = Faker() # Faker('ko')

data = []
for _ in range(100):
    person_data = {
        '이름': fake.name(),
        '주소': fake.address(),
        '전화번호': fake.phone_number(),
        '직업': fake.job(),
        '이메일': fake.email()
    }
    data.append(person_data)

# Optional: Print the first few entries to verify
for i in range(5):
    print(data[i])
    print("-" * 20)
# Out:
# {'이름': 'William Washington', '주소': '0852 Mary Inlet Apt. 926\nNew Meghanton, SD 03963', '전화번호': '823-233-0039', '직업': 'Psychiatric nurse', '이메일': 'jennifer00@example.net'}
# --------------------
# {'이름': 'John Lopez', '주소': '216 Seth View\nGallowaystad, MH 13388', '전화번호': '970.950.6299x0311', '직업': 'Chief Operating Officer', '이메일': 'colleen05@example.net'}
# --------------------
# {'이름': 'Sara Oneal', '주소': '937 Joseph Islands\nObrienmouth, MA 20443', '전화번호': '(996)208-3669x661', '직업': 'Clinical research associate', '이메일': 'corey01@example.org'}
# --------------------
# {'이름': 'Casey Novak', '주소': '30504 Robinson Mountains Suite 245\nStacyside, PW 85867', '전화번호': '472.407.6001', '직업': 'Publishing copy', '이메일': 'justin72@example.com'}
# --------------------
# {'이름': 'Diana Reese', '주소': '553 Neal Turnpike Suite 274\nMartinbury, WI 45875', '전화번호': '429.609.1516x3712', '직업': 'Chief Financial Officer', '이메일': 'hensonandrea@example.org'}
# --------------------

# %%
data
# Out:
# [{'이름': 'William Washington',
#   '주소': '0852 Mary Inlet Apt. 926\nNew Meghanton, SD 03963',
#   '전화번호': '823-233-0039',
#   '직업': 'Psychiatric nurse',
#   '이메일': 'jennifer00@example.net'},
#  {'이름': 'John Lopez',
#   '주소': '216 Seth View\nGallowaystad, MH 13388',
#   '전화번호': '970.950.6299x0311',
#   '직업': 'Chief Operating Officer',
#   '이메일': 'colleen05@example.net'},
#  {'이름': 'Sara Oneal',
#   '주소': '937 Joseph Islands\nObrienmouth, MA 20443',
#   '전화번호': '(996)208-3669x661',
#   '직업': 'Clinical research associate',
#   '이메일': 'corey01@example.org'},
#  {'이름': 'Casey Novak',
#   '주소': '30504 Robinson Mountains Suite 245\nStacyside, PW 85867',
#   '전화번호': '472.407.6001',
#   '직업': 'Publishing copy',
#   '이메일': 'justin72@example.com'},
#  {'이름': 'Diana Reese',
#   '주소': '553 Neal Turnpike Suite 274\nMartinbury, WI 45875',
#   '전화번호': '429.609.1516x3712',
#   '직업': 'Chief Financial Officer',
#   '이메일': 'hensonandrea@example.org'},
#  {'이름': 'Susan Thompson',
#   '주소': '69243 Ian Falls Apt. 508\nMayostad, NJ 69579',
#   '전화번호': '631.322.1366',
#   '직업': 'Chartered public finance accountant',
#   '이메일': 'sanchezdiana@example.net'},
#  {'이름': 'Rebekah Barker',
#   '주소': '4925 Lawrence Shoals\nCaseyville, NV 48166',
#   '전화번호': '001-239-242-3048x450',
#   '직업': 'Data processing manager',
#   '이메일': 'hallalexis@example.org'},
#  {'이름': 'Melissa Powell',
#   '주소': '4963 Sharon Prairie Apt. 148\nWest Lynn, VT 03991',
#   '전화번호': '685-836-0409',
#   '직업': 'Company secretary',
#   '이메일': 'jay23@example.net'},
#  {'이름': 'Cory Cummings',
#   '주소': '8407 Lisa Causeway Apt. 673\nFloydview, GU 80289',
#   '전화번호': '001-955-741-3928x7456',
#   '직업': 'Editor, commissioning',
#   '이메일': 'moyerjesus@example.org'},
#  {'이름': 'Joan Roberts',
#   '주소': '9451 Harold Extensions\nSchroedershire, MS 22316',
#   '전화번호': '+1-334-455-4466x3890',
#   '직업': 'Community pharmacist',
#   '이메일': 'moyerjoy@example.net'},
#  {'이름': 'Monique Mcintosh',
#   '주소': '7798 Lewis Manors Apt. 505\nMichelleborough, CA 35702',
#   '전화번호': '+1-977-576-8224x4860',
#   '직업': 'Air traffic controller',
#   '이메일': 'jaimemcfarland@example.net'},
#  {'이름': 'Karla Bullock',
#   '주소': '286 Flowers Common\nNorth Katherine, IL 76288',
#   '전화번호': '+1-750-982-2886x503',
#   '직업': 'Theatre manager',
#   '이메일': 'michaelfuentes@example.net'},
#  {'이름': 'Aaron Johnson',
#   '주소': '114 Amy Row\nNew Jamesfort, FL 25423',
#   '전화번호': '662.959.1830x1949',
#   '직업': 'Science writer',
#   '이메일': 'moodylauren@example.com'},
#  {'이름': 'Megan Brooks',
#   '주소': 'USCGC Vazquez\nFPO AE 13161',
#   '전화번호': '001-504-220-0092x800',
#   '직업': 'Insurance underwriter',
#   '이메일': 'allenjames@example.com'},
#  {'이름': 'Adam Frazier',
#   '주소': '40569 Sandra Forge\nNorth Ashley, TN 33915',
#   '전화번호': '7559188853',
#   '직업': 'Architectural technologist',
#   '이메일': 'michaelcarlson@example.org'},
#  {'이름': 'Colleen Baker',
#   '주소': '546 Francis Villages\nSouth Paul, AR 83684',
#   '전화번호': '+1-454-678-1472x006',
#   '직업': 'Producer, radio',
#   '이메일': 'ericmartinez@example.org'},
#  {'이름': 'Cameron Mcintosh',
#   '주소': 'Unit 0170 Box 1623\nDPO AA 39701',
#   '전화번호': '001-810-449-7707',
#   '직업': 'Embryologist, clinical',
#   '이메일': 'hilldebra@example.net'},
#  {'이름': 'Julie Holden',
#   '주소': '6616 Jeffrey View Apt. 461\nLake Sandy, WV 30882',
#   '전화번호': '9666942522',
#   '직업': 'Horticulturist, commercial',
#   '이메일': 'johnsonkenneth@example.net'},
#  {'이름': 'George Young',
#   '주소': '1656 Brown Village Apt. 366\nMooreborough, MO 79980',
#   '전화번호': '(328)359-6711',
#   '직업': 'Systems analyst',
#   '이메일': 'mccormickmarie@example.org'},
#  {'이름': 'Tony Combs',
#   '주소': '684 Steven Drives\nPort Seanbury, OH 65213',
#   '전화번호': '+1-550-308-0030x35563',
#   '직업': 'Civil engineer, contracting',
#   '이메일': 'bgonzalez@example.org'},
#  {'이름': 'Ann Bowen',
#   '주소': '157 Matthew Estate Suite 474\nMartinfurt, PR 42590',
#   '전화번호': '738.234.3029x2444',
#   '직업': 'Restaurant manager',
#   '이메일': 'tstephens@example.com'},
#  {'이름': 'Angela White',
#   '주소': 'Unit 7857 Box 3205\nDPO AP 17685',
#   '전화번호': '335-467-0187x70111',
#   '직업': 'Estate manager/land agent',
#   '이메일': 'thood@example.net'},
#  {'이름': 'Stephen Brown',
#   '주소': '07223 Pennington Cove Suite 368\nEast Tiffany, MP 70952',
#   '전화번호': '(431)507-2153x6108',
#   '직업': 'Surveyor, mining',
#   '이메일': 'efowler@example.com'},
#  {'이름': 'Steven Lara',
#   '주소': '3023 Blackwell Land\nPort Alexander, VT 93529',
#   '전화번호': '(223)820-0688x152',
#   '직업': 'Fisheries officer',
#   '이메일': 'lanemelissa@example.com'},
#  {'이름': 'Tracy Armstrong',
#   '주소': '6257 Meyer River Apt. 535\nCatherinestad, NY 91950',
#   '전화번호': '(212)445-9875x048',
#   '직업': 'Therapist, drama',
#   '이메일': 'ywhitney@example.com'},
#  {'이름': 'Michael Fleming',
#   '주소': '3296 Donna Track Suite 358\nAshleyfort, CA 03590',
#   '전화번호': '984.869.5994x559',
#   '직업': 'Insurance risk surveyor',
#   '이메일': 'sturner@example.org'},
#  {'이름': 'John Howard',
#   '주소': '7158 Randall Plaza Suite 162\nLewisville, KY 50413',
#   '전화번호': '773-379-6454x994',
#   '직업': 'Chief of Staff',
#   '이메일': 'pereznancy@example.org'},
#  {'이름': 'Mrs. Brenda Watson',
#   '주소': 'USCGC Ramirez\nFPO AE 24336',
#   '전화번호': '+1-391-652-8161x99499',
#   '직업': 'Television/film/video producer',
#   '이메일': 'garzamegan@example.com'},
#  {'이름': 'James Keller',
#   '주소': '5334 Christopher Valley\nGrahammouth, CA 11648',
#   '전화번호': '(450)884-5396x3942',
#   '직업': "Politician's assistant",
#   '이메일': 'katelynrush@example.org'},
#  {'이름': 'Megan Myers',
#   '주소': '738 Rodgers Lock Apt. 595\nGregoryville, NV 77484',
#   '전화번호': '757-629-2463x09122',
#   '직업': 'Applications developer',
#   '이메일': 'jason40@example.net'},
#  {'이름': 'Hayley Taylor',
#   '주소': '11271 Irwin Ways\nEast Lori, ID 55376',
#   '전화번호': '(930)621-3780',
#   '직업': 'Child psychotherapist',
#   '이메일': 'psmith@example.org'},
#  {'이름': 'Nicholas Thompson',
#   '주소': '26113 Katie Lodge\nGillhaven, AZ 88287',
#   '전화번호': '001-538-443-6508x46595',
#   '직업': 'Surveyor, rural practice',
#   '이메일': 'rrose@example.com'},
#  {'이름': 'James Jones',
#   '주소': '764 Mckee Stravenue\nNorth Brooke, ME 86517',
#   '전화번호': '(603)405-2359x63847',
#   '직업': 'Buyer, industrial',
#   '이메일': 'idiaz@example.net'},
#  {'이름': 'Christine Bryant',
#   '주소': '1320 Adam Cove Suite 010\nEast Curtismouth, HI 01800',
#   '전화번호': '(720)839-1049x0810',
#   '직업': 'Designer, industrial/product',
#   '이메일': 'todd73@example.org'},
#  {'이름': 'Misty Thomas',
#   '주소': '25987 Richardson Mews Apt. 042\nWest Lauren, WV 67435',
#   '전화번호': '2632030685',
#   '직업': 'Hospital doctor',
#   '이메일': 'haleyalexander@example.org'},
#  {'이름': 'Lauren Hernandez',
#   '주소': '563 Pratt Tunnel Apt. 467\nWilliamburgh, SC 62850',
#   '전화번호': '267.747.4800',
#   '직업': 'Physicist, medical',
#   '이메일': 'zdavis@example.org'},
#  {'이름': 'Derrick Porter',
#   '주소': '8382 Daniel Fields Suite 451\nNew Deborahbury, FM 36487',
#   '전화번호': '624-381-9178x582',
#   '직업': 'Public relations account executive',
#   '이메일': 'johnsoncassidy@example.org'},
#  {'이름': 'Jared Mueller',
#   '주소': 'USNV Mendoza\nFPO AP 16048',
#   '전화번호': '309-931-1468',
#   '직업': 'Geneticist, molecular',
#   '이메일': 'vaustin@example.org'},
#  {'이름': 'John Smith',
#   '주소': '09037 Karen Knoll Apt. 554\nPetersport, IN 06766',
#   '전화번호': '001-967-718-1872x487',
#   '직업': 'Government social research officer',
#   '이메일': 'timothy09@example.com'},
#  {'이름': 'Troy Landry',
#   '주소': 'USS Lynch\nFPO AA 33898',
#   '전화번호': '516-887-1044x2026',
#   '직업': 'Manufacturing systems engineer',
#   '이메일': 'smithbrooke@example.com'},
#  {'이름': 'Ashley Campbell',
#   '주소': '92478 Pamela Rapids\nLake Tammychester, AZ 58326',
#   '전화번호': '(696)641-1879x474',
#   '직업': 'Commercial horticulturist',
#   '이메일': 'larrycampbell@example.net'},
#  {'이름': 'Paul Howell',
#   '주소': '43061 Jason Estates\nNorth Tracyton, MP 97838',
#   '전화번호': '(575)783-9040',
#   '직업': 'Archivist',
#   '이메일': 'abigailali@example.org'},
#  {'이름': 'Brian Holland',
#   '주소': '873 Thompson Stream Suite 053\nSouth Laura, MO 91357',
#   '전화번호': '001-513-563-6414x99545',
#   '직업': 'Magazine journalist',
#   '이메일': 'madelinedavis@example.net'},
#  {'이름': 'Tammy Bradley',
#   '주소': '9707 Hill Club Apt. 088\nPaulmouth, WI 46779',
#   '전화번호': '+1-426-494-3777x388',
#   '직업': 'Advertising art director',
#   '이메일': 'erik20@example.net'},
#  {'이름': 'Charlotte Morse',
#   '주소': 'USCGC Carter\nFPO AE 29796',
#   '전화번호': '+1-305-731-0417x978',
#   '직업': 'Radiographer, diagnostic',
#   '이메일': 'moorebetty@example.net'},
#  {'이름': 'Tamara Norris',
#   '주소': '3791 Richmond Field Suite 663\nLake Williamberg, OH 63322',
#   '전화번호': '740.577.0412x1625',
#   '직업': 'Academic librarian',
#   '이메일': 'michael33@example.org'},
#  {'이름': 'Christopher Bond',
#   '주소': '888 Katie Divide Apt. 416\nSouth Fredericktown, WV 31431',
#   '전화번호': '+1-962-859-5596x06701',
#   '직업': 'Quantity surveyor',
#   '이메일': 'william15@example.com'},
#  {'이름': 'Jose Robinson',
#   '주소': '12272 Jerry Fords\nLarryport, ME 57056',
#   '전화번호': '001-935-879-4762x94667',
#   '직업': 'Neurosurgeon',
#   '이메일': 'chelseykennedy@example.net'},
#  {'이름': 'Deborah Jones',
#   '주소': '2809 Misty Tunnel\nLake Veronica, MT 15683',
#   '전화번호': '(226)308-4563',
#   '직업': 'Speech and language therapist',
#   '이메일': 'matthew73@example.net'},
#  {'이름': 'Robert Hernandez',
#   '주소': '373 Kayla Springs Suite 478\nPort Anthonymouth, TN 52829',
#   '전화번호': '309-988-0958x597',
#   '직업': 'Psychologist, clinical',
#   '이메일': 'shannonreed@example.net'},
#  {'이름': 'Alexis Jones',
#   '주소': '1189 Aaron Crossroad\nCristinaland, MT 83670',
#   '전화번호': '816.403.2073x2139',
#   '직업': 'Artist',
#   '이메일': 'michael57@example.com'},
#  {'이름': 'Samuel Bradshaw',
#   '주소': '9880 Jordan Meadow\nThomasside, GA 09140',
#   '전화번호': '001-282-860-2173',
#   '직업': 'Manufacturing engineer',
#   '이메일': 'austin50@example.org'},
#  {'이름': 'April Nguyen',
#   '주소': '061 Pamela Ways\nNew Carlos, DE 96080',
#   '전화번호': '(241)614-6708x1549',
#   '직업': 'Lighting technician, broadcasting/film/video',
#   '이메일': 'jasonvelasquez@example.net'},
#  {'이름': 'Darren Yang',
#   '주소': '035 Gonzales Shores\nNew Haroldstad, PA 69020',
#   '전화번호': '9942748053',
#   '직업': 'Health visitor',
#   '이메일': 'campbellholly@example.com'},
#  {'이름': 'Brooke George',
#   '주소': '69728 Emily Squares Apt. 577\nSouth Jonathanborough, DE 91836',
#   '전화번호': '9407377943',
#   '직업': 'Research officer, political party',
#   '이메일': 'hnielsen@example.com'},
#  {'이름': 'Brittany Cameron',
#   '주소': '255 Andrew Bridge\nSouth Donnafurt, SC 65119',
#   '전화번호': '2632576951',
#   '직업': 'Technical author',
#   '이메일': 'marissa01@example.org'},
#  {'이름': 'Aaron Moody',
#   '주소': '0979 Ashley Mews Suite 434\nNew John, ND 17353',
#   '전화번호': '414-890-3290',
#   '직업': 'Lecturer, higher education',
#   '이메일': 'jwright@example.com'},
#  {'이름': 'Donald Quinn',
#   '주소': '5044 Melvin Knolls Apt. 943\nWest Christopher, GA 06646',
#   '전화번호': '905-946-0001x111',
#   '직업': 'Chartered legal executive (England and Wales)',
#   '이메일': 'paullee@example.com'},
#  {'이름': 'Ann Velasquez',
#   '주소': 'PSC 3145, Box 8763\nAPO AE 47825',
#   '전화번호': '951.574.3371x217',
#   '직업': 'Armed forces operational officer',
#   '이메일': 'wsalazar@example.net'},
#  {'이름': 'Brenda Pratt',
#   '주소': '607 Douglas Streets\nNorth Victoria, WY 40154',
#   '전화번호': '(516)814-7479x79733',
#   '직업': 'Amenity horticulturist',
#   '이메일': 'ysweeney@example.org'},
#  {'이름': 'Andrew Orr',
#   '주소': '878 Evans Prairie Apt. 122\nPort Brandon, TX 21331',
#   '전화번호': '001-910-524-9218x35930',
#   '직업': 'Psychologist, educational',
#   '이메일': 'respinoza@example.org'},
#  {'이름': 'Diane Burnett',
#   '주소': '42740 Lauren Unions Suite 612\nSouth Carmen, VI 96180',
#   '전화번호': '(217)689-8440',
#   '직업': 'Legal secretary',
#   '이메일': 'jacob19@example.org'},
#  {'이름': 'Christopher Brown',
#   '주소': '30798 Robinson Meadows\nTonyaport, SC 89594',
#   '전화번호': '830-875-4040',
#   '직업': 'Designer, blown glass/stained glass',
#   '이메일': 'njones@example.net'},
#  {'이름': 'Jennifer Perez',
#   '주소': '8786 Mills Plains Apt. 940\nPort David, WI 72162',
#   '전화번호': '(350)606-4114x1322',
#   '직업': 'Industrial/product designer',
#   '이메일': 'richard31@example.org'},
#  {'이름': 'Stephanie Miles',
#   '주소': 'USNS Walker\nFPO AP 80654',
#   '전화번호': '6289842166',
#   '직업': 'Nutritional therapist',
#   '이메일': 'danielleholloway@example.org'},
#  {'이름': 'Michael Ewing',
#   '주소': '626 Teresa Cape Suite 870\nJohnsonmouth, MT 08643',
#   '전화번호': '812-311-4725x430',
#   '직업': 'Operational investment banker',
#   '이메일': 'tinawilliams@example.com'},
#  {'이름': 'Rebecca Young',
#   '주소': '41014 Olson Pine\nEast Brianview, PW 97503',
#   '전화번호': '769.805.0321x808',
#   '직업': 'Surveyor, planning and development',
#   '이메일': 'haley32@example.net'},
#  {'이름': 'Andrew Hutchinson',
#   '주소': '135 Bowen Street\nNew Jason, AK 37343',
#   '전화번호': '(265)534-5438x3738',
#   '직업': 'Sports therapist',
#   '이메일': 'shanelyons@example.com'},
#  {'이름': 'Brent Marquez',
#   '주소': 'USNS Berg\nFPO AE 51863',
#   '전화번호': '001-858-349-7561x056',
#   '직업': 'Engineer, materials',
#   '이메일': 'christina87@example.net'},
#  {'이름': 'Daniel Beasley',
#   '주소': 'USS Woods\nFPO AP 27117',
#   '전화번호': '384.347.3764',
#   '직업': 'Equality and diversity officer',
#   '이메일': 'ramirezarthur@example.org'},
#  {'이름': 'Michael Evans',
#   '주소': '267 Kelly Stream Suite 004\nKennedyberg, AK 60247',
#   '전화번호': '932.752.7757',
#   '직업': 'Surveyor, quantity',
#   '이메일': 'kking@example.net'},
#  {'이름': 'David Hubbard',
#   '주소': '50713 Edward Isle\nLoweton, TN 55739',
#   '전화번호': '(647)637-0723',
#   '직업': 'Microbiologist',
#   '이메일': 'laurenhodge@example.org'},
#  {'이름': 'Rachel Ruiz',
#   '주소': '0807 Moody Forks\nNew Sabrinaview, AR 22049',
#   '전화번호': '+1-512-907-3770x2339',
#   '직업': 'Scientist, physiological',
#   '이메일': 'walkersamantha@example.org'},
#  {'이름': 'Juan Morris',
#   '주소': '64541 Larson Light Apt. 124\nHaasfurt, FL 13755',
#   '전화번호': '+1-203-888-8868',
#   '직업': 'Sales professional, IT',
#   '이메일': 'danielrichards@example.com'},
#  {'이름': 'Tiffany Sellers',
#   '주소': '237 Nathaniel Road Apt. 761\nPort Heatherland, AL 67665',
#   '전화번호': '7864508034',
#   '직업': 'Teacher, early years/pre',
#   '이메일': 'lewispaula@example.org'},
#  {'이름': 'Christopher Mcfarland',
#   '주소': '2340 Denise Land\nEast Johnton, CT 73788',
#   '전화번호': '001-397-360-8131x33794',
#   '직업': 'Surveyor, commercial/residential',
#   '이메일': 'christopherrichardson@example.org'},
#  {'이름': 'Megan Warren',
#   '주소': '2729 Kenneth Underpass Suite 858\nNorth Eric, AL 74445',
#   '전화번호': '7669564021',
#   '직업': 'Actor',
#   '이메일': 'eclark@example.net'},
#  {'이름': 'Bethany Moody',
#   '주소': 'PSC 6342, Box 8844\nAPO AE 75016',
#   '전화번호': '+1-981-805-8515x823',
#   '직업': 'Sports coach',
#   '이메일': 'cindy70@example.com'},
#  {'이름': 'Antonio Robbins',
#   '주소': '83562 Walter Lake Apt. 685\nKarenmouth, NH 66636',
#   '전화번호': '921-345-7497x81355',
#   '직업': 'Recruitment consultant',
#   '이메일': 'mdavidson@example.org'},
#  {'이름': 'Ryan Smith',
#   '주소': '97033 Evans Inlet\nJohnsonchester, VT 17866',
#   '전화번호': '566-723-1243x0252',
#   '직업': 'Training and development officer',
#   '이메일': 'amandaespinoza@example.org'},
#  {'이름': 'Shaun Shah',
#   '주소': '36144 Wilson Greens Suite 350\nWoodardbury, AS 66935',
#   '전화번호': '759-934-2880',
#   '직업': 'Psychologist, occupational',
#   '이메일': 'hortonlauren@example.com'},
#  {'이름': 'James Watts',
#   '주소': '860 Ricky Key\nMartinezside, AZ 86515',
#   '전화번호': '(742)760-6296x4407',
#   '직업': 'Tour manager',
#   '이메일': 'jared16@example.net'},
#  {'이름': 'Michael Turner',
#   '주소': '5166 Tucker Rapids\nMooreport, MT 24587',
#   '전화번호': '452.867.8746x546',
#   '직업': 'Horticulturist, amenity',
#   '이메일': 'aliciafry@example.com'},
#  {'이름': 'Dawn Brooks',
#   '주소': '0813 Davis Walk Apt. 531\nTorresburgh, OR 41194',
#   '전화번호': '847-298-0484x043',
#   '직업': 'Magazine journalist',
#   '이메일': 'ryanbrian@example.net'},
#  {'이름': 'Daniel Richards',
#   '주소': '0962 Williams Points\nAvilamouth, CA 69981',
#   '전화번호': '(595)681-5260x082',
#   '직업': 'Museum/gallery curator',
#   '이메일': 'dan13@example.net'},
#  {'이름': 'Erik Reyes',
#   '주소': '866 Ryan Turnpike Suite 549\nGeorgebury, MS 91135',
#   '전화번호': '418-728-1496x18527',
#   '직업': 'Chief of Staff',
#   '이메일': 'plawson@example.org'},
#  {'이름': 'Sarah Figueroa',
#   '주소': '99608 Landry Haven Suite 153\nNew Nathanfort, AL 91202',
#   '전화번호': '001-445-728-8088x236',
#   '직업': 'International aid/development worker',
#   '이메일': 'tinaandrews@example.org'},
#  {'이름': 'Holly Smith',
#   '주소': '9679 Johnson Walks\nKingchester, CO 19831',
#   '전화번호': '+1-616-542-2809x2590',
#   '직업': 'Cytogeneticist',
#   '이메일': 'stephanieroth@example.com'},
#  {'이름': 'Joseph Boyle',
#   '주소': '473 House Gateway\nMooreberg, TX 01492',
#   '전화번호': '673-381-6235',
#   '직업': 'Embryologist, clinical',
#   '이메일': 'kimeric@example.org'},
#  {'이름': 'Jerome Frank',
#   '주소': '99881 Nathan Spring\nMorganberg, PW 15251',
#   '전화번호': '(376)526-3961x46800',
#   '직업': 'Printmaker',
#   '이메일': 'mario24@example.com'},
#  {'이름': 'John Stone',
#   '주소': '262 Martinez Lake\nWillieport, VA 54425',
#   '전화번호': '7535428634',
#   '직업': 'Financial manager',
#   '이메일': 'samuel18@example.org'},
#  {'이름': 'Dennis Phelps',
#   '주소': '59000 Nicole Dam Apt. 694\nGrossville, WV 84037',
#   '전화번호': '(753)976-9289',
#   '직업': 'Administrator, sports',
#   '이메일': 'kleinrebecca@example.com'},
#  {'이름': 'Melissa Johnson',
#   '주소': '6551 Davis Lakes\nDawnshire, MS 48089',
#   '전화번호': '+1-758-250-0879x5908',
#   '직업': 'Facilities manager',
#   '이메일': 'andrew43@example.com'},
#  {'이름': 'Bradley Oconnor',
#   '주소': '03588 Whitaker Junction\nSandrabury, WY 78329',
#   '전화번호': '+1-424-660-6112x375',
#   '직업': 'Production engineer',
#   '이메일': 'ptaylor@example.net'},
#  {'이름': 'Linda Stout',
#   '주소': '596 Nicholson Union Suite 466\nJacquelineview, RI 59768',
#   '전화번호': '4132331102',
#   '직업': 'Engineer, maintenance (IT)',
#   '이메일': 'melaniedavis@example.com'},
#  {'이름': 'Amy White',
#   '주소': '52418 Darlene Lodge Apt. 290\nSchneiderview, UT 21506',
#   '전화번호': '492-921-6380',
#   '직업': 'Tax adviser',
#   '이메일': 'tamara98@example.org'},
#  {'이름': 'Willie Torres',
#   '주소': '80721 Harris Hill Apt. 302\nJacksonmouth, MA 19855',
#   '전화번호': '001-456-533-3175x62052',
#   '직업': 'Merchant navy officer',
#   '이메일': 'lcarpenter@example.com'},
#  {'이름': 'Amy Morgan',
#   '주소': '89108 Ernest Ridge Suite 538\nNorth Michaelview, KS 09861',
#   '전화번호': '785.908.1734',
#   '직업': 'Designer, interior/spatial',
#   '이메일': 'heather96@example.net'},
#  {'이름': 'Ruth Ramirez',
#   '주소': '1588 Karen Valley Apt. 596\nPort Clarenceshire, TN 12307',
#   '전화번호': '001-326-534-5006x81329',
#   '직업': 'Leisure centre manager',
#   '이메일': 'catherineli@example.org'},
#  {'이름': 'Cheyenne Ponce',
#   '주소': '19977 Hamilton Flat Apt. 293\nLake Jonathan, FL 60768',
#   '전화번호': '780.377.0042x50785',
#   '직업': 'Chemist, analytical',
#   '이메일': 'alexandra29@example.net'}]

# %%
import pandas as pd

df = pd.DataFrame(data)
df
# Out:
#                     이름                                                 주소  \
# 0   William Washington  0852 Mary Inlet Apt. 926\nNew Meghanton, SD 03963
# 1           John Lopez              216 Seth View\nGallowaystad, MH 13388
# 2           Sara Oneal          937 Joseph Islands\nObrienmouth, MA 20443
# 3          Casey Novak  30504 Robinson Mountains Suite 245\nStacyside,...
# 4          Diana Reese  553 Neal Turnpike Suite 274\nMartinbury, WI 45875
# ..                 ...                                                ...
# 95           Amy White  52418 Darlene Lodge Apt. 290\nSchneiderview, U...
# 96       Willie Torres  80721 Harris Hill Apt. 302\nJacksonmouth, MA 1...
# 97          Amy Morgan  89108 Ernest Ridge Suite 538\nNorth Michaelvie...
# 98        Ruth Ramirez  1588 Karen Valley Apt. 596\nPort Clarenceshire...
# 99      Cheyenne Ponce  19977 Hamilton Flat Apt. 293\nLake Jonathan, F...
#
#                       전화번호                           직업  \
# 0             823-233-0039            Psychiatric nurse
# 1        970.950.6299x0311      Chief Operating Officer
# 2        (996)208-3669x661  Clinical research associate
# 3             472.407.6001              Publishing copy
# 4        429.609.1516x3712      Chief Financial Officer
# ..                     ...                          ...
# 95            492-921-6380                  Tax adviser
# 96  001-456-533-3175x62052        Merchant navy officer
# 97            785.908.1734   Designer, interior/spatial
# 98  001-326-534-5006x81329       Leisure centre manager
# 99      780.377.0042x50785          Chemist, analytical
#
#                          이메일
# 0     jennifer00@example.net
# 1      colleen05@example.net
# 2        corey01@example.org
# 3       justin72@example.com
# 4   hensonandrea@example.org
# ..                       ...
# 95      tamara98@example.org
# 96    lcarpenter@example.com
# 97     heather96@example.net
# 98   catherineli@example.org
# 99   alexandra29@example.net
#
# [100 rows x 5 columns]
